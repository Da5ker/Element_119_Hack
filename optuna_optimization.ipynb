# %%
import pandas as pd
import numpy as np
import random
from datetime import datetime

import torch
from lightning import pytorch as pl
from lightning.pytorch.callbacks import EarlyStopping
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import optuna
from optuna.pruners import MedianPruner
from optuna.integration import PyTorchLightningPruningCallback

from chemprop.data import MoleculeDatapoint, MoleculeDataset
from chemprop.nn import BondMessagePassing, MeanAggregation, SumAggregation, NormAggregation, AttentiveAggregation, RegressionFFN
from chemprop.models import MPNN
from chemprop.data import build_dataloader
from chemprop.nn.transforms import UnscaleTransform, ScaleTransform
from chemprop.nn.metrics import RMSE
from chemprop.featurizers import SimpleMoleculeMolGraphFeaturizer

from rdkit import Chem
from rdkit.Chem import Descriptors, rdMolDescriptors
from mordred import Calculator, descriptors

# %% [markdown]
# # Оптимизация гиперпараметров и параметрического пространства

# %% [markdown]
# Этот Jupyter notebook посвящён оптимизации гиперпараметров и выбора дескрипторов для модели Chemprop, используемой для предсказания молекулярного свойства LogP. Применяется библиотека Optuna для автоматического подбора оптимальных гиперпараметров и подмножеств дескрипторов, чтобы минимизировать метрику RMSE.

# %%
# Самые влиятельные дескрипторы, отобраны в feature_selection.ipynb
DESCRIPTORS = [
    'FpDensityMorgan1', 'FpDensityMorgan2', 'HeavyAtomMolWt', 'MolWt', 'NumHDonors',
    'NumHAcceptors', 'fr_COO', 'fr_Al_COO', 'fr_Ar_N','fr_Al_OH', 'fr_Ar_NH', 'fr_quatN', 'BertzCT','NumRings', 'NumAromaticRings', 'NumAromaticCarbocycles', 'NumHeteroatoms', 'TPSA', 'LabuteASA', 'CalcKappa3', 'SLogP', 'PEOE_VSA6', 'PEOE_VSA1', 'C2SP2', 'ZMIC1', 'ZMIC2', 'NaasC', 'NsNh2', 'NsOH', 'NdO', 'nX', 'nN', 'VSA_EState6', 'SMR_VSA7', 'AATS1p', 'AATS1v', 'AATS1i', 'AATS2p', 'AATS2v', 'AATS1se', 'AATS0se', 'AATS4s', 'MATS1Z', 'MATS2d', 'MATS1m', 'MATS1pe', 'MATS1se', 'SlogP_VSA7', 'SlogP_VSA8', 'nAcid', 'nBase', 'FilterItLogS', 'nBondsM', 'MIC0', 'EState_VSA5', 'IC5', 'IC0'
    ]

# %% [markdown]
# ## Очистка данных
# Стандартный pipeline очистки, включающий:
# 1) Удаление выбросов IQR-методом по целевому признаку LogP.
# 2) Фильтрация некорректных SMILES.
# 3) Удаление дубликатов SMILES.

# %%
def iqr_remove_outliers(df):
    logp_values = df['LogP']

    Q1 = np.percentile(logp_values, 25)
    Q3 = np.percentile(logp_values, 75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df_clear = df[(logp_values >= lower_bound) & (logp_values <= upper_bound)]
    print(f"Number of outliers removed: {len(df) - len(df_clear)}")
    return df_clear


def remove_invalid_molecules(df):
    invalid_smiles_indices = []
    for index, row in df.iterrows():
        try:
            MoleculeDatapoint.from_smi(row['SMILES'], row['LogP'])
        except Exception as e:
            invalid_smiles_indices.append(index)

    df_clear = df.drop(invalid_smiles_indices)
    print(f"Number of invalid SMILES removed: {len(invalid_smiles_indices)}")
    return df_clear

def remove_duplicate_molecules(df):
   smiles_counts = df['SMILES'].value_counts()
   duplicates = smiles_counts[smiles_counts > 1].index
   df_clear = df[~df['SMILES'].isin(duplicates)]

   print(f"Number of duplicate SMILES removed: {len(duplicates)}")
   return df_clear

# %%
df = pd.read_csv('./data/final_train_data80.csv')
df = iqr_remove_outliers(df)
df = remove_invalid_molecules(df)
df = remove_duplicate_molecules(df)
# Out:
# Number of outliers removed: 401
# [02:13:57] SMILES Parse Error: syntax error while parsing: CC(C)MC1=C(C(N=C2NNN=N2)=O)SC(OC)=C1Br
# [02:13:57] SMILES Parse Error: check for mistakes around position 6:
# [02:13:57] CC(C)MC1=C(C(N=C2NNN=N2)=O)SC(OC)=C1Br
# [02:13:57] ~~~~~^
# [02:13:57] SMILES Parse Error: Failed parsing SMILES 'CC(C)MC1=C(C(N=C2NNN=N2)=O)SC(OC)=C1Br' for input: 'CC(C)MC1=C(C(N=C2NNN=N2)=O)SC(OC)=C1Br'
# [02:13:57] Explicit valence for atom # 8 N, 4, is greater than permitted
# [02:13:57] Explicit valence for atom # 9 C, 5, is greater than permitted
# [02:13:57] SMILES Parse Error: extra open parentheses while parsing: N(C(N=S)CC
# [02:13:57] SMILES Parse Error: check for mistakes around position 2:
# [02:13:57] N(C(N=S)CC
# [02:13:57] ~^
# [02:13:57] SMILES Parse Error: Failed parsing SMILES 'N(C(N=S)CC' for input: 'N(C(N=S)CC'
# [02:13:57] SMILES Parse Error: syntax error while parsing: C1=CC2(C3C(CC4(C)CmO)(C(=O)CO)CCC4C3CCC2=CC1=O)=O)C
# [02:13:57] SMILES Parse Error: check for mistakes around position 19:
# [02:13:57] C1=CC2(C3C(CC4(C)CmO)(C(=O)CO)CCC4C3CCC2=
# [02:13:57] ~~~~~~~~~~~~~~~~~~^
# [02:13:57] SMILES Parse Error: Failed parsing SMILES 'C1=CC2(C3C(CC4(C)CmO)(C(=O)CO)CCC4C3CCC2=CC1=O)=O)C' for input: 'C1=CC2(C3C(CC4(C)CmO)(C(=O)CO)CCC4C3CCC2=CC1=O)=O)C'
# [02:13:57] Explicit valence for atom # 11 C, 5, is greater than permitted
# [02:13:57] Explicit valence for atom # 7 C, 6, is greater than permitted
# [02:13:57] Explicit valence for atom # 1 C, 5, is greater than permitted
# [02:13:58] SMILES Parse Error: extra close parentheses while parsing: C1(=CC=CC=C1)C(=O)C=CCO)=O
# [02:13:58] SMILES Parse Error: check for mistakes around position 24:
# [02:13:58] =CC=CC=C1)C(=O)C=CCO)=O
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C1(=CC=CC=C1)C(=O)C=CCO)=O' for input: 'C1(=CC=CC=C1)C(=O)C=CCO)=O'
# [02:13:58] SMILES Parse Error: syntax error while parsing: CC(C)CC(=O)NC=1C=C(Cl)r(=CC=1)Cl
# [02:13:58] SMILES Parse Error: check for mistakes around position 23:
# [02:13:58] (C)CC(=O)NC=1C=C(Cl)r(=CC=1)Cl
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'CC(C)CC(=O)NC=1C=C(Cl)r(=CC=1)Cl' for input: 'CC(C)CC(=O)NC=1C=C(Cl)r(=CC=1)Cl'
# [02:13:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [02:13:58] SMILES Parse Error: extra close parentheses while parsing: CCC)C(CC1=CC=CC=C1)N
# [02:13:58] SMILES Parse Error: check for mistakes around position 4:
# [02:13:58] CCC)C(CC1=CC=CC=C1)N
# [02:13:58] ~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'CCC)C(CC1=CC=CC=C1)N' for input: 'CCC)C(CC1=CC=CC=C1)N'
# [02:13:58] SMILES Parse Error: extra open parentheses while parsing: N1C(=N)NC=C(C1=NCC2=C(I)C(OC)=C(OC)C(=C2)OC
# [02:13:58] SMILES Parse Error: check for mistakes around position 12:
# [02:13:58] N1C(=N)NC=C(C1=NCC2=C(I)C(OC)=C(OC)C(=C2)
# [02:13:58] ~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'N1C(=N)NC=C(C1=NCC2=C(I)C(OC)=C(OC)C(=C2)OC' for input: 'N1C(=N)NC=C(C1=NCC2=C(I)C(OC)=C(OC)C(=C2)OC'
# [02:13:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [02:13:58] SMILES Parse Error: syntax error while parsing: ClC(ClgC(F)(F)OC
# [02:13:58] SMILES Parse Error: check for mistakes around position 7:
# [02:13:58] ClC(ClgC(F)(F)OC
# [02:13:58] ~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'ClC(ClgC(F)(F)OC' for input: 'ClC(ClgC(F)(F)OC'
# [02:13:58] SMILES Parse Error: extra close parentheses while parsing: C1=C(C(O)=CC=C1)O)[N+]([O-])=O
# [02:13:58] SMILES Parse Error: check for mistakes around position 18:
# [02:13:58] C1=C(C(O)=CC=C1)O)[N+]([O-])=O
# [02:13:58] ~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C1=C(C(O)=CC=C1)O)[N+]([O-])=O' for input: 'C1=C(C(O)=CC=C1)O)[N+]([O-])=O'
# [02:13:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [02:13:58] SMILES Parse Error: extra close parentheses while parsing: C(CO[N+](=O)[O-])OCCO[N+]=O)[O-]
# [02:13:58] SMILES Parse Error: check for mistakes around position 28:
# [02:13:58] ](=O)[O-])OCCO[N+]=O)[O-]
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C(CO[N+](=O)[O-])OCCO[N+]=O)[O-]' for input: 'C(CO[N+](=O)[O-])OCCO[N+]=O)[O-]'
# [02:13:58] non-ring atom 8 marked aromatic
# [02:13:58] Can't kekulize mol.  Unkekulized atoms: 7
# [02:13:58] Can't kekulize mol.  Unkekulized atoms: 4
# [02:13:58] Explicit valence for atom # 10 C, 6, is greater than permitted
# [02:13:58] non-ring atom 17 marked aromatic
# [02:13:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [02:13:58] Explicit valence for atom # 16 C, 5, is greater than permitted
# [02:13:58] non-ring atom 6 marked aromatic
# [02:13:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [02:13:58] SMILES Parse Error: syntax error while parsing: O=S(=O)(CC(=OTC=1C=CC(=CC=1)Cl)C=2C=CC(C)=CC=2
# [02:13:58] SMILES Parse Error: check for mistakes around position 14:
# [02:13:58] O=S(=O)(CC(=OTC=1C=CC(=CC=1)Cl)C=2C=CC(C)
# [02:13:58] ~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'O=S(=O)(CC(=OTC=1C=CC(=CC=1)Cl)C=2C=CC(C)=CC=2' for input: 'O=S(=O)(CC(=OTC=1C=CC(=CC=1)Cl)C=2C=CC(C)=CC=2'
# [02:13:58] SMILES Parse Error: syntax error while parsing: C=1(C(=O)OC2=CC=C(Br)C=C2C=1)C(N(C)CC=3C(=Nr(C=3)CC)C)=O
# [02:13:58] SMILES Parse Error: check for mistakes around position 44:
# [02:13:58] C2C=1)C(N(C)CC=3C(=Nr(C=3)CC)C)=O
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C=1(C(=O)OC2=CC=C(Br)C=C2C=1)C(N(C)CC=3C(=Nr(C=3)CC)C)=O' for input: 'C=1(C(=O)OC2=CC=C(Br)C=C2C=1)C(N(C)CC=3C(=Nr(C=3)CC)C)=O'
# [02:13:58] SMILES Parse Error: unclosed ring for input: 'C1CCCCNCCC(C2=CC=C(C=C2)C)=O'
# [02:13:58] SMILES Parse Error: syntax error while parsing: C(=O)(O)C(C)=CC(=)C=1C=CC(C2=CC=CC=C2Cl)=CC=1
# [02:13:58] SMILES Parse Error: check for mistakes around position 18:
# [02:13:58] C(=O)(O)C(C)=CC(=)C=1C=CC(C2=CC=CC=C2Cl)=
# [02:13:58] ~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C(=O)(O)C(C)=CC(=)C=1C=CC(C2=CC=CC=C2Cl)=CC=1' for input: 'C(=O)(O)C(C)=CC(=)C=1C=CC(C2=CC=CC=C2Cl)=CC=1'
# [02:13:58] SMILES Parse Error: syntax error while parsing: C1CN(CCN1)C=2C(=CC=CC=2)CD
# [02:13:58] SMILES Parse Error: check for mistakes around position 26:
# [02:13:58] CCN1)C=2C(=CC=CC=2)CD
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C1CN(CCN1)C=2C(=CC=CC=2)CD' for input: 'C1CN(CCN1)C=2C(=CC=CC=2)CD'
# [02:13:58] SMILES Parse Error: syntax error while parsing: Ct=CC=2C=3C=CC=CC=3N=[N+](C=2C=C1)[O-]
# [02:13:58] SMILES Parse Error: check for mistakes around position 2:
# [02:13:58] Ct=CC=2C=3C=CC=CC=3N=[N+](C=2C=C1)[O-]
# [02:13:58] ~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'Ct=CC=2C=3C=CC=CC=3N=[N+](C=2C=C1)[O-]' for input: 'Ct=CC=2C=3C=CC=CC=3N=[N+](C=2C=C1)[O-]'
# [02:13:58] SMILES Parse Error: syntax error while parsing: ClC1=CC=CC=C1CX
# [02:13:58] SMILES Parse Error: check for mistakes around position 15:
# [02:13:58] ClC1=CC=CC=C1CX
# [02:13:58] ~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'ClC1=CC=CC=C1CX' for input: 'ClC1=CC=CC=C1CX'
# [02:13:58] Explicit valence for atom # 0 O, 4, is greater than permitted
# [02:13:58] SMILES Parse Error: syntax error while parsing: C(CCOCCOP(OCCOCCCC)(OCCOCCCC)=O)Cd
# [02:13:58] SMILES Parse Error: check for mistakes around position 34:
# [02:13:58] OCCCC)(OCCOCCCC)=O)Cd
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C(CCOCCOP(OCCOCCCC)(OCCOCCCC)=O)Cd' for input: 'C(CCOCCOP(OCCOCCCC)(OCCOCCCC)=O)Cd'
# [02:13:58] non-ring atom 12 marked aromatic
# [02:13:58] SMILES Parse Error: syntax error while parsing: C1CCCN1CCC(=O)C=2SC(=NC)NC=2Ce
# [02:13:58] SMILES Parse Error: check for mistakes around position 30:
# [02:13:58] C(=O)C=2SC(=NC)NC=2Ce
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C1CCCN1CCC(=O)C=2SC(=NC)NC=2Ce' for input: 'C1CCCN1CCC(=O)C=2SC(=NC)NC=2Ce'
# [02:13:58] SMILES Parse Error: syntax error while parsing: OC=1C(=CC(=C(Cl)C=)Cl)OC
# [02:13:58] SMILES Parse Error: check for mistakes around position 19:
# [02:13:58] OC=1C(=CC(=C(Cl)C=)Cl)OC
# [02:13:58] ~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'OC=1C(=CC(=C(Cl)C=)Cl)OC' for input: 'OC=1C(=CC(=C(Cl)C=)Cl)OC'
# [02:13:58] SMILES Parse Error: syntax error while parsing: FC(F)(F)COP(OCC(F)AF)F)(N1CCOCC1)=O
# [02:13:58] SMILES Parse Error: check for mistakes around position 19:
# [02:13:58] FC(F)(F)COP(OCC(F)AF)F)(N1CCOCC1)=O
# [02:13:58] ~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'FC(F)(F)COP(OCC(F)AF)F)(N1CCOCC1)=O' for input: 'FC(F)(F)COP(OCC(F)AF)F)(N1CCOCC1)=O'
# [02:13:58] Explicit valence for atom # 4 C, 7, is greater than permitted
# [02:13:58] Explicit valence for atom # 1 N, 5, is greater than permitted
# [02:13:58] non-ring atom 0 marked aromatic
# [02:13:58] SMILES Parse Error: syntax error while parsing: C(CCNC()=O)C
# [02:13:58] SMILES Parse Error: check for mistakes around position 8:
# [02:13:58] C(CCNC()=O)C
# [02:13:58] ~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C(CCNC()=O)C' for input: 'C(CCNC()=O)C'
# [02:13:58] SMILES Parse Error: extra open parentheses while parsing: O(C(NC)=O)C1=CC=CC(=C1)C(OC=O
# [02:13:58] SMILES Parse Error: check for mistakes around position 25:
# [02:13:58] NC)=O)C1=CC=CC(=C1)C(OC=O
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'O(C(NC)=O)C1=CC=CC(=C1)C(OC=O' for input: 'O(C(NC)=O)C1=CC=CC(=C1)C(OC=O'
# [02:13:58] Explicit valence for atom # 17 N, 4, is greater than permitted
# [02:13:58] SMILES Parse Error: syntax error while parsing: N1C(=NC(=C1)C=2SC=CC=2)C3=CC=C(C=C3)OCC(O)CNCCCd
# [02:13:58] SMILES Parse Error: check for mistakes around position 48:
# [02:13:58] C=C(C=C3)OCC(O)CNCCCd
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'N1C(=NC(=C1)C=2SC=CC=2)C3=CC=C(C=C3)OCC(O)CNCCCd' for input: 'N1C(=NC(=C1)C=2SC=CC=2)C3=CC=C(C=C3)OCC(O)CNCCCd'
# [02:13:58] SMILES Parse Error: syntax error while parsing: CC1=CSC(C=2C(F)=CCM=CC=2)C(C(O)=O)C)=N1
# [02:13:58] SMILES Parse Error: check for mistakes around position 19:
# [02:13:58] CC1=CSC(C=2C(F)=CCM=CC=2)C(C(O)=O)C)=N1
# [02:13:58] ~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'CC1=CSC(C=2C(F)=CCM=CC=2)C(C(O)=O)C)=N1' for input: 'CC1=CSC(C=2C(F)=CCM=CC=2)C(C(O)=O)C)=N1'
# [02:13:58] SMILES Parse Error: syntax error while parsing: CZC=1C(=C(Cl)C(Cl)=CC=1)OC2=CC=CC=C2
# [02:13:58] SMILES Parse Error: check for mistakes around position 2:
# [02:13:58] CZC=1C(=C(Cl)C(Cl)=CC=1)OC2=CC=CC=C2
# [02:13:58] ~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'CZC=1C(=C(Cl)C(Cl)=CC=1)OC2=CC=CC=C2' for input: 'CZC=1C(=C(Cl)C(Cl)=CC=1)OC2=CC=CC=C2'
# [02:13:58] Explicit valence for atom # 5 C, 6, is greater than permitted
# [02:13:58] SMILES Parse Error: syntax error while parsing: (CC)CCC1=CNN=C1
# [02:13:58] SMILES Parse Error: check for mistakes around position 1:
# [02:13:58] (CC)CCC1=CNN=C1
# [02:13:58] ^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES '(CC)CCC1=CNN=C1' for input: '(CC)CCC1=CNN=C1'
# [02:13:58] non-ring atom 12 marked aromatic
# [02:13:58] SMILES Parse Error: syntax error while parsing: C=1C(Cl)=C(C=C(C=1OC)OC)l
# [02:13:58] SMILES Parse Error: check for mistakes around position 25:
# [02:13:58] (Cl)=C(C=C(C=1OC)OC)l
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C=1C(Cl)=C(C=C(C=1OC)OC)l' for input: 'C=1C(Cl)=C(C=C(C=1OC)OC)l'
# [02:13:58] SMILES Parse Error: syntax error while parsing: C(C1=CC=C([N+](dO-])=O)C=C1)CC
# [02:13:58] SMILES Parse Error: check for mistakes around position 16:
# [02:13:58] C(C1=CC=C([N+](dO-])=O)C=C1)CC
# [02:13:58] ~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C(C1=CC=C([N+](dO-])=O)C=C1)CC' for input: 'C(C1=CC=C([N+](dO-])=O)C=C1)CC'
# [02:13:58] SMILES Parse Error: syntax error while parsing: C(CCCOC(C=1Nt(NC(=O)C=1)=O)=O)CCCC
# [02:13:58] SMILES Parse Error: check for mistakes around position 13:
# [02:13:58] C(CCCOC(C=1Nt(NC(=O)C=1)=O)=O)CCCC
# [02:13:58] ~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C(CCCOC(C=1Nt(NC(=O)C=1)=O)=O)CCCC' for input: 'C(CCCOC(C=1Nt(NC(=O)C=1)=O)=O)CCCC'
# [02:13:58] Explicit valence for atom # 1 S, 8, is greater than permitted
# [02:13:58] SMILES Parse Error: extra close parentheses while parsing: N(O)=CC1=CC=CC=C1)F
# [02:13:58] SMILES Parse Error: check for mistakes around position 18:
# [02:13:58] N(O)=CC1=CC=CC=C1)F
# [02:13:58] ~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'N(O)=CC1=CC=CC=C1)F' for input: 'N(O)=CC1=CC=CC=C1)F'
# [02:13:58] SMILES Parse Error: extra open parentheses while parsing: C(NC(CC1=CC=C(C=C1O)C(NC)=O)(=O)C
# [02:13:58] SMILES Parse Error: check for mistakes around position 2:
# [02:13:58] C(NC(CC1=CC=C(C=C1O)C(NC)=O)(=O)C
# [02:13:58] ~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C(NC(CC1=CC=C(C=C1O)C(NC)=O)(=O)C' for input: 'C(NC(CC1=CC=C(C=C1O)C(NC)=O)(=O)C'
# [02:13:58] non-ring atom 3 marked aromatic
# [02:13:58] SMILES Parse Error: syntax error while parsing: C(C=1SC2=C(C=CC=C2)C=1Cl)(=O)NCC3CCCO3e
# [02:13:58] SMILES Parse Error: check for mistakes around position 39:
# [02:13:58] )C=1Cl)(=O)NCC3CCCO3e
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C(C=1SC2=C(C=CC=C2)C=1Cl)(=O)NCC3CCCO3e' for input: 'C(C=1SC2=C(C=CC=C2)C=1Cl)(=O)NCC3CCCO3e'
# [02:13:58] SMILES Parse Error: syntax error while parsing: CC(C)C(NC(=O)C(C(C)CC)NC(=O)C(NC(C(C(CC)C)N)=O)CC=1C=CC(O)=CC=1)C(=O)OG
# [02:13:58] SMILES Parse Error: check for mistakes around position 71:
# [02:13:58] 1C=CC(O)=CC=1)C(=O)OG
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'CC(C)C(NC(=O)C(C(C)CC)NC(=O)C(NC(C(C(CC)C)N)=O)CC=1C=CC(O)=CC=1)C(=O)OG' for input: 'CC(C)C(NC(=O)C(C(C)CC)NC(=O)C(NC(C(C(CC)C)N)=O)CC=1C=CC(O)=CC=1)C(=O)OG'
# [02:13:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [02:13:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [02:13:58] SMILES Parse Error: syntax error while parsing: C=1C2(C)C3(C(CC4(C(CC(C4(O)C(CCl)=O)C)C3CC=C2CC(=O)C=1)C)O)Fm
# [02:13:58] SMILES Parse Error: check for mistakes around position 61:
# [02:13:58] CC=C2CC(=O)C=1)C)O)Fm
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C=1C2(C)C3(C(CC4(C(CC(C4(O)C(CCl)=O)C)C3CC=C2CC(=O)C=1)C)O)Fm' for input: 'C=1C2(C)C3(C(CC4(C(CC(C4(O)C(CCl)=O)C)C3CC=C2CC(=O)C=1)C)O)Fm'
# [02:13:58] SMILES Parse Error: syntax error while parsing: C1(=CC=CC(=C1NC2rNCCN2)Cl)C
# [02:13:58] SMILES Parse Error: check for mistakes around position 17:
# [02:13:58] C1(=CC=CC(=C1NC2rNCCN2)Cl)C
# [02:13:58] ~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C1(=CC=CC(=C1NC2rNCCN2)Cl)C' for input: 'C1(=CC=CC(=C1NC2rNCCN2)Cl)C'
# [02:13:58] SMILES Parse Error: syntax error while parsing: N1N=l(OC1=N)CCC
# [02:13:58] SMILES Parse Error: check for mistakes around position 5:
# [02:13:58] N1N=l(OC1=N)CCC
# [02:13:58] ~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'N1N=l(OC1=N)CCC' for input: 'N1N=l(OC1=N)CCC'
# [02:13:58] SMILES Parse Error: syntax error while parsing: C=1C(Br)=CC=C2C=1CC=3C2=CC=C(C=3)ND
# [02:13:58] SMILES Parse Error: check for mistakes around position 35:
# [02:13:58] C=1CC=3C2=CC=C(C=3)ND
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C=1C(Br)=CC=C2C=1CC=3C2=CC=C(C=3)ND' for input: 'C=1C(Br)=CC=C2C=1CC=3C2=CC=C(C=3)ND'
# [02:13:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [02:13:58] SMILES Parse Error: syntax error while parsing: C(N(C(C(=O)NC=1g(C)=CC=CC=1C)CC)CCC)C
# [02:13:58] SMILES Parse Error: check for mistakes around position 16:
# [02:13:58] C(N(C(C(=O)NC=1g(C)=CC=CC=1C)CC)CCC)C
# [02:13:58] ~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C(N(C(C(=O)NC=1g(C)=CC=CC=1C)CC)CCC)C' for input: 'C(N(C(C(=O)NC=1g(C)=CC=CC=1C)CC)CCC)C'
# [02:13:58] SMILES Parse Error: extra open parentheses while parsing: C1CCCC1(NC(=O)N(N=OCCCl)C(=O)O
# [02:13:58] SMILES Parse Error: check for mistakes around position 8:
# [02:13:58] C1CCCC1(NC(=O)N(N=OCCCl)C(=O)O
# [02:13:58] ~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C1CCCC1(NC(=O)N(N=OCCCl)C(=O)O' for input: 'C1CCCC1(NC(=O)N(N=OCCCl)C(=O)O'
# [02:13:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [02:13:58] Explicit valence for atom # 4 C, 7, is greater than permitted
# [02:13:58] Explicit valence for atom # 1 C, 6, is greater than permitted
# [02:13:58] SMILES Parse Error: syntax error while parsing: ClCMCl)(Cl)C(NC(=O)OCC)O
# [02:13:58] SMILES Parse Error: check for mistakes around position 4:
# [02:13:58] ClCMCl)(Cl)C(NC(=O)OCC)O
# [02:13:58] ~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'ClCMCl)(Cl)C(NC(=O)OCC)O' for input: 'ClCMCl)(Cl)C(NC(=O)OCC)O'
# [02:13:58] Explicit valence for atom # 6 O, 5, is greater than permitted
# [02:13:58] Explicit valence for atom # 21 C, 5, is greater than permitted
# [02:13:58] Explicit valence for atom # 4 S, 9, is greater than permitted
# [02:13:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [02:13:58] SMILES Parse Error: syntax error while parsing: C1CN(CCN1C2=CC=CC=C2OC)CCC=CC=3C=CC(F)=CC=
# [02:13:58] SMILES Parse Error: check for mistakes around position 42:
# [02:13:58] C)CCC=CC=3C=CC(F)=CC=
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C1CN(CCN1C2=CC=CC=C2OC)CCC=CC=3C=CC(F)=CC=' for input: 'C1CN(CCN1C2=CC=CC=C2OC)CCC=CC=3C=CC(F)=CC='
# [02:13:58] Explicit valence for atom # 18 O, 5, is greater than permitted
# [02:13:58] non-ring atom 8 marked aromatic
# [02:13:58] SMILES Parse Error: extra close parentheses while parsing: C(NC=O)C)C1=CC=CC=C1
# [02:13:58] SMILES Parse Error: check for mistakes around position 9:
# [02:13:58] C(NC=O)C)C1=CC=CC=C1
# [02:13:58] ~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C(NC=O)C)C1=CC=CC=C1' for input: 'C(NC=O)C)C1=CC=CC=C1'
# [02:13:58] Explicit valence for atom # 11 N, 5, is greater than permitted
# [02:13:58] SMILES Parse Error: syntax error while parsing: C=1C(Cl)=C(OCC#C)C(Cl)=CC=1N=CNOCCG
# [02:13:58] SMILES Parse Error: check for mistakes around position 35:
# [02:13:58] #C)C(Cl)=CC=1N=CNOCCG
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C=1C(Cl)=C(OCC#C)C(Cl)=CC=1N=CNOCCG' for input: 'C=1C(Cl)=C(OCC#C)C(Cl)=CC=1N=CNOCCG'
# [02:13:58] SMILES Parse Error: unclosed ring for input: 'C=C2C(C=C(C=C2)OC)=CC=C1CC(=O)OCC(NCC)=O'
# [02:13:58] SMILES Parse Error: syntax error while parsing: O=S(=O)(N)C=1C=CC(=CC=1)C(=O)OCCCd
# [02:13:58] SMILES Parse Error: check for mistakes around position 34:
# [02:13:58] C=CC(=CC=1)C(=O)OCCCd
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'O=S(=O)(N)C=1C=CC(=CC=1)C(=O)OCCCd' for input: 'O=S(=O)(N)C=1C=CC(=CC=1)C(=O)OCCCd'
# [02:13:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [02:13:58] Explicit valence for atom # 7 C, 7, is greater than permitted
# [02:13:58] SMILES Parse Error: syntax error while parsing: C(CCC)N(CCCC)CCS(=O)(=)C1=CC(OC)=C(OC)C(OC)=C1
# [02:13:58] SMILES Parse Error: check for mistakes around position 23:
# [02:13:58] CCC)N(CCCC)CCS(=O)(=)C1=CC(OC)=C(OC)C(OC)
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C(CCC)N(CCCC)CCS(=O)(=)C1=CC(OC)=C(OC)C(OC)=C1' for input: 'C(CCC)N(CCCC)CCS(=O)(=)C1=CC(OC)=C(OC)C(OC)=C1'
# [02:13:58] SMILES Parse Error: syntax error while parsing: C1CN(TCO1)CCOC(=O)NC=2C(=CC=CC=2)OCCCCC
# [02:13:58] SMILES Parse Error: check for mistakes around position 6:
# [02:13:58] C1CN(TCO1)CCOC(=O)NC=2C(=CC=CC=2)OCCCCC
# [02:13:58] ~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C1CN(TCO1)CCOC(=O)NC=2C(=CC=CC=2)OCCCCC' for input: 'C1CN(TCO1)CCOC(=O)NC=2C(=CC=CC=2)OCCCCC'
# [02:13:58] SMILES Parse Error: syntax error while parsing: C1(=CC(C(CC(CC(=O)O)C)=O)=CC=C1OC)Cla
# [02:13:58] SMILES Parse Error: check for mistakes around position 37:
# [02:13:58] O)O)C)=O)=CC=C1OC)Cla
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C1(=CC(C(CC(CC(=O)O)C)=O)=CC=C1OC)Cla' for input: 'C1(=CC(C(CC(CC(=O)O)C)=O)=CC=C1OC)Cla'
# [02:13:58] SMILES Parse Error: syntax error while parsing: CG(=NC(C2=CC=CC=C2)=NO1)C=NO
# [02:13:58] SMILES Parse Error: check for mistakes around position 2:
# [02:13:58] CG(=NC(C2=CC=CC=C2)=NO1)C=NO
# [02:13:58] ~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'CG(=NC(C2=CC=CC=C2)=NO1)C=NO' for input: 'CG(=NC(C2=CC=CC=C2)=NO1)C=NO'
# [02:13:58] SMILES Parse Error: syntax error while parsing: O=S1(=O)C2=CC(=CC(Cl)=C2NC(CCC(=O)O)=N1)ClD
# [02:13:58] SMILES Parse Error: check for mistakes around position 43:
# [02:13:58] C2NC(CCC(=O)O)=N1)ClD
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'O=S1(=O)C2=CC(=CC(Cl)=C2NC(CCC(=O)O)=N1)ClD' for input: 'O=S1(=O)C2=CC(=CC(Cl)=C2NC(CCC(=O)O)=N1)ClD'
# [02:13:58] SMILES Parse Error: syntax error while parsing: CC1(C)C(N2CT=O)C(NC(=O)CC3=CC=CC=C3)C2S1)C(O)=O
# [02:13:58] SMILES Parse Error: check for mistakes around position 12:
# [02:13:58] CC1(C)C(N2CT=O)C(NC(=O)CC3=CC=CC=C3)C2S1)
# [02:13:58] ~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'CC1(C)C(N2CT=O)C(NC(=O)CC3=CC=CC=C3)C2S1)C(O)=O' for input: 'CC1(C)C(N2CT=O)C(NC(=O)CC3=CC=CC=C3)C2S1)C(O)=O'
# [02:13:58] SMILES Parse Error: syntax error while parsing: OC(=O)C(NC(C(CCC(=O)N)N)=O)CC1=CC=CC=C1R
# [02:13:58] SMILES Parse Error: check for mistakes around position 40:
# [02:13:58] )N)N)=O)CC1=CC=CC=C1R
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'OC(=O)C(NC(C(CCC(=O)N)N)=O)CC1=CC=CC=C1R' for input: 'OC(=O)C(NC(C(CCC(=O)N)N)=O)CC1=CC=CC=C1R'
# [02:13:58] SMILES Parse Error: syntax error while parsing: C(=C)CC(CC=C)(d(=O)OC)C(=O)NC(N)=O
# [02:13:58] SMILES Parse Error: check for mistakes around position 15:
# [02:13:58] C(=C)CC(CC=C)(d(=O)OC)C(=O)NC(N)=O
# [02:13:58] ~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C(=C)CC(CC=C)(d(=O)OC)C(=O)NC(N)=O' for input: 'C(=C)CC(CC=C)(d(=O)OC)C(=O)NC(N)=O'
# [02:13:58] Explicit valence for atom # 10 N, 6, is greater than permitted
# [02:13:58] Explicit valence for atom # 1 N, 6, is greater than permitted
# [02:13:58] SMILES Parse Error: syntax error while parsing: CC(C)CC(C(O)=O)NC(=O)C1CCCN1C(C(N)CC(C)C)=Oe
# [02:13:58] SMILES Parse Error: check for mistakes around position 44:
# [02:13:58] CCCN1C(C(N)CC(C)C)=Oe
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'CC(C)CC(C(O)=O)NC(=O)C1CCCN1C(C(N)CC(C)C)=Oe' for input: 'CC(C)CC(C(O)=O)NC(=O)C1CCCN1C(C(N)CC(C)C)=Oe'
# [02:13:58] Explicit valence for atom # 12 C, 6, is greater than permitted
# [02:13:58] Explicit valence for atom # 10 C, 6, is greater than permitted
# [02:13:58] SMILES Parse Error: syntax error while parsing: C[N+](C)(CCZCCCCC)CCS(=O)(=O)[O-]
# [02:13:58] SMILES Parse Error: check for mistakes around position 12:
# [02:13:58] C[N+](C)(CCZCCCCC)CCS(=O)(=O)[O-]
# [02:13:58] ~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C[N+](C)(CCZCCCCC)CCS(=O)(=O)[O-]' for input: 'C[N+](C)(CCZCCCCC)CCS(=O)(=O)[O-]'
# [02:13:58] Explicit valence for atom # 1 N, 4, is greater than permitted
# [02:13:58] SMILES Parse Error: syntax error while parsing: CN(C)C(N(SN(C(=O)ON=C(C)SC)C)C)=OM
# [02:13:58] SMILES Parse Error: check for mistakes around position 34:
# [02:13:58] (=O)ON=C(C)SC)C)C)=OM
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'CN(C)C(N(SN(C(=O)ON=C(C)SC)C)C)=OM' for input: 'CN(C)C(N(SN(C(=O)ON=C(C)SC)C)C)=OM'
# [02:13:58] SMILES Parse Error: syntax error while parsing: CC(C)NCC(OC(C)=O)COC1=CC=CC=2C=CC=CC1=2L
# [02:13:58] SMILES Parse Error: check for mistakes around position 40:
# [02:13:58] C1=CC=CC=2C=CC=CC1=2L
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'CC(C)NCC(OC(C)=O)COC1=CC=CC=2C=CC=CC1=2L' for input: 'CC(C)NCC(OC(C)=O)COC1=CC=CC=2C=CC=CC1=2L'
# [02:13:58] SMILES Parse Error: syntax error while parsing: C=1C=CC=C2OC(COC=12)CNC(=O)C(=O)NC(C)CCC=3CXCC=CC=3
# [02:13:58] SMILES Parse Error: check for mistakes around position 44:
# [02:13:58] (=O)C(=O)NC(C)CCC=3CXCC=CC=3
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C=1C=CC=C2OC(COC=12)CNC(=O)C(=O)NC(C)CCC=3CXCC=CC=3' for input: 'C=1C=CC=C2OC(COC=12)CNC(=O)C(=O)NC(C)CCC=3CXCC=CC=3'
# [02:13:58] SMILES Parse Error: extra close parentheses while parsing: CC1=CC=C(C=C1)C(=O)O)CC
# [02:13:58] SMILES Parse Error: check for mistakes around position 21:
# [02:13:58] CC1=CC=C(C=C1)C(=O)O)CC
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'CC1=CC=C(C=C1)C(=O)O)CC' for input: 'CC1=CC=C(C=C1)C(=O)O)CC'
# [02:13:58] SMILES Parse Error: syntax error while parsing: N1=C(C(=NC(OC)=O)NO1)CG
# [02:13:58] SMILES Parse Error: check for mistakes around position 23:
# [02:13:58] =C(C(=NC(OC)=O)NO1)CG
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'N1=C(C(=NC(OC)=O)NO1)CG' for input: 'N1=C(C(=NC(OC)=O)NO1)CG'
# [02:13:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [02:13:58] SMILES Parse Error: syntax error while parsing: C=1N(CCOC2=CC=C(Br)C=C2)C3=C(NC(=O)N(C)C3=N)N=
# [02:13:58] SMILES Parse Error: check for mistakes around position 46:
# [02:13:58] 3=C(NC(=O)N(C)C3=N)N=
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C=1N(CCOC2=CC=C(Br)C=C2)C3=C(NC(=O)N(C)C3=N)N=' for input: 'C=1N(CCOC2=CC=C(Br)C=C2)C3=C(NC(=O)N(C)C3=N)N='
# [02:13:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [02:13:58] Explicit valence for atom # 3 C, 6, is greater than permitted
# [02:13:58] SMILES Parse Error: unclosed ring for input: 'C1=NC2=C(C(=NC)N)N=CN2C3OC(CC3F)CO'
# [02:13:58] SMILES Parse Error: syntax error while parsing: N(C)C(=O)N(C)C(=)NC1=CC(=CC=C1F)C(C)=O
# [02:13:58] SMILES Parse Error: check for mistakes around position 17:
# [02:13:58] N(C)C(=O)N(C)C(=)NC1=CC(=CC=C1F)C(C)=O
# [02:13:58] ~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'N(C)C(=O)N(C)C(=)NC1=CC(=CC=C1F)C(C)=O' for input: 'N(C)C(=O)N(C)C(=)NC1=CC(=CC=C1F)C(C)=O'
# [02:13:58] SMILES Parse Error: syntax error while parsing: CON(C)N=NC=1C=CC(=CC=1)C(=O)NT
# [02:13:58] SMILES Parse Error: check for mistakes around position 30:
# [02:13:58] C=1C=CC(=CC=1)C(=O)NT
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'CON(C)N=NC=1C=CC(=CC=1)C(=O)NT' for input: 'CON(C)N=NC=1C=CC(=CC=1)C(=O)NT'
# [02:13:58] Explicit valence for atom # 15 C, 5, is greater than permitted
# [02:13:58] Explicit valence for atom # 5 N, 5, is greater than permitted
# [02:13:58] Explicit valence for atom # 9 N, 5, is greater than permitted
# [02:13:58] SMILES Parse Error: syntax error while parsing: C=1([N+](=O)[O-])C([N+]([O-])=O)=CC(=CC=1)Clr
# [02:13:58] SMILES Parse Error: check for mistakes around position 45:
# [02:13:58] [O-])=O)=CC(=CC=1)Clr
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C=1([N+](=O)[O-])C([N+]([O-])=O)=CC(=CC=1)Clr' for input: 'C=1([N+](=O)[O-])C([N+]([O-])=O)=CC(=CC=1)Clr'
# [02:13:58] SMILES Parse Error: extra close parentheses while parsing: C1(=C(CC=C(C(C)=O)C(OCC)=O)=CC=C1)OC)OC
# [02:13:58] SMILES Parse Error: check for mistakes around position 37:
# [02:13:58] O)C(OCC)=O)=CC=C1)OC)OC
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C1(=C(CC=C(C(C)=O)C(OCC)=O)=CC=C1)OC)OC' for input: 'C1(=C(CC=C(C(C)=O)C(OCC)=O)=CC=C1)OC)OC'
# [02:13:58] Explicit valence for atom # 1 O, 4, is greater than permitted
# [02:13:58] SMILES Parse Error: syntax error while parsing: CC1(C)CC=2N(C(C(C#N)C(C=2C(=O)C1)C=3C=C(C(OC)=CC=3)OC)=N)C4=CC=C(Cl)C=C4T
# [02:13:58] SMILES Parse Error: check for mistakes around position 73:
# [02:13:58] C)=N)C4=CC=C(Cl)C=C4T
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'CC1(C)CC=2N(C(C(C#N)C(C=2C(=O)C1)C=3C=C(C(OC)=CC=3)OC)=N)C4=CC=C(Cl)C=C4T' for input: 'CC1(C)CC=2N(C(C(C#N)C(C=2C(=O)C1)C=3C=C(C(OC)=CC=3)OC)=N)C4=CC=C(Cl)C=C4T'
# [02:13:58] SMILES Parse Error: syntax error while parsing: CC(C)CC(NN)=OT
# [02:13:58] SMILES Parse Error: check for mistakes around position 14:
# [02:13:58] CC(C)CC(NN)=OT
# [02:13:58] ~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'CC(C)CC(NN)=OT' for input: 'CC(C)CC(NN)=OT'
# [02:13:58] SMILES Parse Error: syntax error while parsing: C1N(CCOC1(O)C2=CC=C(Br)C=C2)CM
# [02:13:58] SMILES Parse Error: check for mistakes around position 30:
# [02:13:58] (O)C2=CC=C(Br)C=C2)CM
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C1N(CCOC1(O)C2=CC=C(Br)C=C2)CM' for input: 'C1N(CCOC1(O)C2=CC=C(Br)C=C2)CM'
# [02:13:58] Explicit valence for atom # 13 C, 5, is greater than permitted
# [02:13:58] Explicit valence for atom # 18 C, 5, is greater than permitted
# [02:13:58] Explicit valence for atom # 16 C, 5, is greater than permitted
# [02:13:58] Explicit valence for atom # 2 C, 6, is greater than permitted
# [02:13:58] SMILES Parse Error: syntax error while parsing: N1=CC=CC=2C=CC=C(Cl)C1=L
# [02:13:58] SMILES Parse Error: check for mistakes around position 24:
# [02:13:58] CC=CC=2C=CC=C(Cl)C1=L
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'N1=CC=CC=2C=CC=C(Cl)C1=L' for input: 'N1=CC=CC=2C=CC=C(Cl)C1=L'
# [02:13:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [02:13:58] SMILES Parse Error: syntax error while parsing: C1=NC(C2=NC=3C(=CC=CC=3)N2C(OC)=O)=CS1E
# [02:13:58] SMILES Parse Error: check for mistakes around position 39:
# [02:13:58] =CC=3)N2C(OC)=O)=CS1E
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C1=NC(C2=NC=3C(=CC=CC=3)N2C(OC)=O)=CS1E' for input: 'C1=NC(C2=NC=3C(=CC=CC=3)N2C(OC)=O)=CS1E'
# [02:13:58] SMILES Parse Error: syntax error while parsing: C1CCCC(C)C1NC(COC2=NC=NC=3C=CC=CC2=3)=Ot
# [02:13:58] SMILES Parse Error: check for mistakes around position 40:
# [02:13:58] NC=NC=3C=CC=CC2=3)=Ot
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C1CCCC(C)C1NC(COC2=NC=NC=3C=CC=CC2=3)=Ot' for input: 'C1CCCC(C)C1NC(COC2=NC=NC=3C=CC=CC2=3)=Ot'
# [02:13:58] SMILES Parse Error: syntax error while parsing: CC(C)C(NC(=O)C(C)N)C(=O)NC(C(O)=O)C(C)tC
# [02:13:58] SMILES Parse Error: check for mistakes around position 39:
# [02:13:58] )C(=O)NC(C(O)=O)C(C)tC
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'CC(C)C(NC(=O)C(C)N)C(=O)NC(C(O)=O)C(C)tC' for input: 'CC(C)C(NC(=O)C(C)N)C(=O)NC(C(O)=O)C(C)tC'
# [02:13:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [02:13:58] Explicit valence for atom # 13 C, 5, is greater than permitted
# [02:13:58] SMILES Parse Error: extra open parentheses while parsing: CCN(CCCC1=CC=CN=C1
# [02:13:58] SMILES Parse Error: check for mistakes around position 4:
# [02:13:58] CCN(CCCC1=CC=CN=C1
# [02:13:58] ~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'CCN(CCCC1=CC=CN=C1' for input: 'CCN(CCCC1=CC=CN=C1'
# [02:13:58] SMILES Parse Error: unclosed ring for input: 'C1CN(CCN1C=NC=3C=C(OC)C(OC)=CC=3C(=N)N=2)C(=O)C(C)OC'
# [02:13:58] SMILES Parse Error: extra open parentheses while parsing: C(=O)(C)OC1CC(C(=CC(OC(=O)C(C)=CCC2C(=C)C(OC2C=C1C)=O)C)O
# [02:13:58] SMILES Parse Error: check for mistakes around position 14:
# [02:13:58] C(=O)(C)OC1CC(C(=CC(OC(=O)C(C)=CCC2C(=C)C
# [02:13:58] ~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C(=O)(C)OC1CC(C(=CC(OC(=O)C(C)=CCC2C(=C)C(OC2C=C1C)=O)C)O' for input: 'C(=O)(C)OC1CC(C(=CC(OC(=O)C(C)=CCC2C(=C)C(OC2C=C1C)=O)C)O'
# [02:13:58] Explicit valence for atom # 0 C, 5, is greater than permitted
# [02:13:58] SMILES Parse Error: syntax error while parsing: C1(C(=C(C)N=C2N1C=CC=C2)CCC)MO
# [02:13:58] SMILES Parse Error: check for mistakes around position 29:
# [02:13:58] C)N=C2N1C=CC=C2)CCC)MO
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C1(C(=C(C)N=C2N1C=CC=C2)CCC)MO' for input: 'C1(C(=C(C)N=C2N1C=CC=C2)CCC)MO'
# [02:13:58] SMILES Parse Error: syntax error while parsing: C1=C(C2=C(C=CC=N2)C(CC(=O)OC)=C1)OA
# [02:13:58] SMILES Parse Error: check for mistakes around position 35:
# [02:13:58] =N2)C(CC(=O)OC)=C1)OA
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C1=C(C2=C(C=CC=N2)C(CC(=O)OC)=C1)OA' for input: 'C1=C(C2=C(C=CC=N2)C(CC(=O)OC)=C1)OA'
# [02:13:58] SMILES Parse Error: syntax error while parsing: C=1N(CC2=CC=CC=C2F)C(=S)NC=1A
# [02:13:58] SMILES Parse Error: check for mistakes around position 29:
# [02:13:58] =CC=CC=C2F)C(=S)NC=1A
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C=1N(CC2=CC=CC=C2F)C(=S)NC=1A' for input: 'C=1N(CC2=CC=CC=C2F)C(=S)NC=1A'
# [02:13:58] Explicit valence for atom # 1 N, 4, is greater than permitted
# [02:13:58] SMILES Parse Error: extra close parentheses while parsing: C1=CC(=CCN1)=NCCCC)C=2NNC(=N)N=2
# [02:13:58] SMILES Parse Error: check for mistakes around position 19:
# [02:13:58] C1=CC(=CCN1)=NCCCC)C=2NNC(=N)N=2
# [02:13:58] ~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C1=CC(=CCN1)=NCCCC)C=2NNC(=N)N=2' for input: 'C1=CC(=CCN1)=NCCCC)C=2NNC(=N)N=2'
# [02:13:58] SMILES Parse Error: syntax error while parsing: N1C(=O)C(C(NC1=OR=O)(CC)CC(C)C(C)C
# [02:13:58] SMILES Parse Error: check for mistakes around position 17:
# [02:13:58] N1C(=O)C(C(NC1=OR=O)(CC)CC(C)C(C)C
# [02:13:58] ~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'N1C(=O)C(C(NC1=OR=O)(CC)CC(C)C(C)C' for input: 'N1C(=O)C(C(NC1=OR=O)(CC)CC(C)C(C)C'
# [02:13:58] SMILES Parse Error: syntax error while parsing: FC()(F)C=1C=C(C(Cl)=CC=1)NN=C(C(=O)C)C#N
# [02:13:58] SMILES Parse Error: check for mistakes around position 4:
# [02:13:58] FC()(F)C=1C=C(C(Cl)=CC=1)NN=C(C(=O)C)C#N
# [02:13:58] ~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'FC()(F)C=1C=C(C(Cl)=CC=1)NN=C(C(=O)C)C#N' for input: 'FC()(F)C=1C=C(C(Cl)=CC=1)NN=C(C(=O)C)C#N'
# [02:13:58] SMILES Parse Error: syntax error while parsing: C=1C(=CC=C2C=1N=CC=d2)O
# [02:13:58] SMILES Parse Error: check for mistakes around position 20:
# [02:13:58] C=1C(=CC=C2C=1N=CC=d2)O
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C=1C(=CC=C2C=1N=CC=d2)O' for input: 'C=1C(=CC=C2C=1N=CC=d2)O'
# [02:13:58] SMILES Parse Error: syntax error while parsing: C(C)N(CC)CC(=O)TC1COC=2C1=CC(=CC=2)C
# [02:13:58] SMILES Parse Error: check for mistakes around position 16:
# [02:13:58] C(C)N(CC)CC(=O)TC1COC=2C1=CC(=CC=2)C
# [02:13:58] ~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C(C)N(CC)CC(=O)TC1COC=2C1=CC(=CC=2)C' for input: 'C(C)N(CC)CC(=O)TC1COC=2C1=CC(=CC=2)C'
# [02:13:58] Explicit valence for atom # 0 C, 5, is greater than permitted
# [02:13:58] SMILES Parse Error: syntax error while parsing: ClC=1C(OC)=CC(=(C=1Cl)Cl)Cl
# [02:13:58] SMILES Parse Error: check for mistakes around position 16:
# [02:13:58] ClC=1C(OC)=CC(=(C=1Cl)Cl)Cl
# [02:13:58] ~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'ClC=1C(OC)=CC(=(C=1Cl)Cl)Cl' for input: 'ClC=1C(OC)=CC(=(C=1Cl)Cl)Cl'
# [02:13:58] SMILES Parse Error: syntax error while parsing: O=C(NC)C1N(CCC1)Ct=O)C
# [02:13:58] SMILES Parse Error: check for mistakes around position 18:
# [02:13:58] O=C(NC)C1N(CCC1)Ct=O)C
# [02:13:58] ~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'O=C(NC)C1N(CCC1)Ct=O)C' for input: 'O=C(NC)C1N(CCC1)Ct=O)C'
# [02:13:58] SMILES Parse Error: syntax error while parsing: C1(C)=C(C(C(=O)NCMCCCCCC)=NN1)[N+]([O-])=O
# [02:13:58] SMILES Parse Error: check for mistakes around position 18:
# [02:13:58] C1(C)=C(C(C(=O)NCMCCCCCC)=NN1)[N+]([O-])=
# [02:13:58] ~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C1(C)=C(C(C(=O)NCMCCCCCC)=NN1)[N+]([O-])=O' for input: 'C1(C)=C(C(C(=O)NCMCCCCCC)=NN1)[N+]([O-])=O'
# [02:13:58] SMILES Parse Error: syntax error while parsing: N1C=2N(CC=C)C=NC=2C(N(C)C1=O)RN
# [02:13:58] SMILES Parse Error: check for mistakes around position 30:
# [02:13:58] =C)C=NC=2C(N(C)C1=O)RN
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'N1C=2N(CC=C)C=NC=2C(N(C)C1=O)RN' for input: 'N1C=2N(CC=C)C=NC=2C(N(C)C1=O)RN'
# [02:13:58] Explicit valence for atom # 11 C, 5, is greater than permitted
# [02:13:58] SMILES Parse Error: extra open parentheses while parsing: C1(C(C(C(C(C1Cl)Cl)ClCl)Cl)Cl
# [02:13:58] SMILES Parse Error: check for mistakes around position 3:
# [02:13:58] C1(C(C(C(C(C1Cl)Cl)ClCl)Cl)Cl
# [02:13:58] ~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C1(C(C(C(C(C1Cl)Cl)ClCl)Cl)Cl' for input: 'C1(C(C(C(C(C1Cl)Cl)ClCl)Cl)Cl'
# [02:13:58] SMILES Parse Error: syntax error while parsing: C1=CC=C2C(=C1)C(C=3C(=CC=CC=3)S2)=OG
# [02:13:58] SMILES Parse Error: check for mistakes around position 36:
# [02:13:58] (C=3C(=CC=CC=3)S2)=OG
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C1=CC=C2C(=C1)C(C=3C(=CC=CC=3)S2)=OG' for input: 'C1=CC=C2C(=C1)C(C=3C(=CC=CC=3)S2)=OG'
# [02:13:58] non-ring atom 18 marked aromatic
# [02:13:58] SMILES Parse Error: syntax error while parsing: C(OC)A=O)C([N+](=O)[O-])=CC1=CC=C(I)O1
# [02:13:58] SMILES Parse Error: check for mistakes around position 6:
# [02:13:58] C(OC)A=O)C([N+](=O)[O-])=CC1=CC=C(I)O1
# [02:13:58] ~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C(OC)A=O)C([N+](=O)[O-])=CC1=CC=C(I)O1' for input: 'C(OC)A=O)C([N+](=O)[O-])=CC1=CC=C(I)O1'
# [02:13:58] non-ring atom 9 marked aromatic
# [02:13:58] Explicit valence for atom # 2 C, 5, is greater than permitted
# [02:13:58] SMILES Parse Error: syntax error while parsing: FC(F)(F)CT=CC=C(C(=C1)Cl)OC2=CC=C(C(=C2)OC(C)C(=O)OC=C)[N+](=O)[O-]
# [02:13:58] SMILES Parse Error: check for mistakes around position 10:
# [02:13:58] FC(F)(F)CT=CC=C(C(=C1)Cl)OC2=CC=C(C(=C2)O
# [02:13:58] ~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'FC(F)(F)CT=CC=C(C(=C1)Cl)OC2=CC=C(C(=C2)OC(C)C(=O)OC=C)[N+](=O)[O-]' for input: 'FC(F)(F)CT=CC=C(C(=C1)Cl)OC2=CC=C(C(=C2)OC(C)C(=O)OC=C)[N+](=O)[O-]'
# [02:13:58] SMILES Parse Error: syntax error while parsing: N1C=CC=2C(C=C(C3=CC=C(OCRC=C3OC)N=2)=C1
# [02:13:58] SMILES Parse Error: check for mistakes around position 25:
# [02:13:58] CC=2C(C=C(C3=CC=C(OCRC=C3OC)N=2)=C1
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'N1C=CC=2C(C=C(C3=CC=C(OCRC=C3OC)N=2)=C1' for input: 'N1C=CC=2C(C=C(C3=CC=C(OCRC=C3OC)N=2)=C1'
# [02:13:58] non-ring atom 10 marked aromatic
# [02:13:58] Explicit valence for atom # 11 C, 5, is greater than permitted
# [02:13:58] Explicit valence for atom # 0 N, 4, is greater than permitted
# [02:13:58] Explicit valence for atom # 2 N, 4, is greater than permitted
# [02:13:58] SMILES Parse Error: extra close parentheses while parsing: FC(F)(F)C1=CC=C(OC=2C=C(C([N+]([O-])=O)=CC=2)C(=NOCC=O)OC)C)C(=C1)Cl
# [02:13:58] SMILES Parse Error: check for mistakes around position 60:
# [02:13:58] =CC=2)C(=NOCC=O)OC)C)C(=C1)Cl
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'FC(F)(F)C1=CC=C(OC=2C=C(C([N+]([O-])=O)=CC=2)C(=NOCC=O)OC)C)C(=C1)Cl' for input: 'FC(F)(F)C1=CC=C(OC=2C=C(C([N+]([O-])=O)=CC=2)C(=NOCC=O)OC)C)C(=C1)Cl'
# [02:13:58] non-ring atom 10 marked aromatic
# [02:13:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [02:13:58] SMILES Parse Error: unclosed ring for input: 'CC(C)C(N(CS1)S(=O)(=O)C=2C=NN(C)C=2)C(=O)NC(C(=O)OC(C)C)CC=3C=CC(OC(=O)N(C)C)=CC=3'
# [02:13:58] SMILES Parse Error: syntax error while parsing: tC(F)(F)CN(C)C
# [02:13:58] SMILES Parse Error: check for mistakes around position 1:
# [02:13:58] tC(F)(F)CN(C)C
# [02:13:58] ^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'tC(F)(F)CN(C)C' for input: 'tC(F)(F)CN(C)C'
# [02:13:58] SMILES Parse Error: syntax error while parsing: O(C=1R2=C(C(OC)=NN=1)C=CC=C2)C
# [02:13:58] SMILES Parse Error: check for mistakes around position 6:
# [02:13:58] O(C=1R2=C(C(OC)=NN=1)C=CC=C2)C
# [02:13:58] ~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'O(C=1R2=C(C(OC)=NN=1)C=CC=C2)C' for input: 'O(C=1R2=C(C(OC)=NN=1)C=CC=C2)C'
# [02:13:58] Explicit valence for atom # 17 C, 5, is greater than permitted
# [02:13:58] SMILES Parse Error: extra open parentheses while parsing: C1(=CC=C([N+]([O-]=O)C=C1)C(NN)=O
# [02:13:58] SMILES Parse Error: check for mistakes around position 3:
# [02:13:58] C1(=CC=C([N+]([O-]=O)C=C1)C(NN)=O
# [02:13:58] ~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C1(=CC=C([N+]([O-]=O)C=C1)C(NN)=O' for input: 'C1(=CC=C([N+]([O-]=O)C=C1)C(NN)=O'
# [02:13:58] SMILES Parse Error: syntax error while parsing: C1CN(CCN1C2=CC=C(C(Cl)=C2)Cl)CC3CNC(=N)O3t
# [02:13:58] SMILES Parse Error: check for mistakes around position 42:
# [02:13:58] )=C2)Cl)CC3CNC(=N)O3t
# [02:13:58] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C1CN(CCN1C2=CC=C(C(Cl)=C2)Cl)CC3CNC(=N)O3t' for input: 'C1CN(CCN1C2=CC=C(C(Cl)=C2)Cl)CC3CNC(=N)O3t'
# [02:13:58] SMILES Parse Error: syntax error while parsing: C=1eC=CC=C(F)C=1N=CC=C2
# [02:13:58] SMILES Parse Error: check for mistakes around position 4:
# [02:13:58] C=1eC=CC=C(F)C=1N=CC=C2
# [02:13:58] ~~~^
# [02:13:58] SMILES Parse Error: Failed parsing SMILES 'C=1eC=CC=C(F)C=1N=CC=C2' for input: 'C=1eC=CC=C(F)C=1N=CC=C2'
# [02:13:58] Explicit valence for atom # 7 C, 5, is greater than permitted
# [02:13:59] non-ring atom 27 marked aromatic
# [02:13:59] SMILES Parse Error: syntax error while parsing: O=C1NrCCCCC2N=CC1C(OCC)=O
# [02:13:59] SMILES Parse Error: check for mistakes around position 6:
# [02:13:59] O=C1NrCCCCC2N=CC1C(OCC)=O
# [02:13:59] ~~~~~^
# [02:13:59] SMILES Parse Error: Failed parsing SMILES 'O=C1NrCCCCC2N=CC1C(OCC)=O' for input: 'O=C1NrCCCCC2N=CC1C(OCC)=O'
# [02:13:59] SMILES Parse Error: syntax error while parsing: C=1C(=NC(C2=CC=CC=C2)=NC=XCl)Cl
# [02:13:59] SMILES Parse Error: check for mistakes around position 26:
# [02:13:59] =NC(C2=CC=CC=C2)=NC=XCl)Cl
# [02:13:59] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:59] SMILES Parse Error: Failed parsing SMILES 'C=1C(=NC(C2=CC=CC=C2)=NC=XCl)Cl' for input: 'C=1C(=NC(C2=CC=CC=C2)=NC=XCl)Cl'
# [02:13:59] Explicit valence for atom # 10 C, 6, is greater than permitted
# [02:13:59] Explicit valence for atom # 1 C, 5, is greater than permitted
# [02:13:59] Explicit valence for atom # 5 C, 6, is greater than permitted
# [02:13:59] SMILES Parse Error: syntax error while parsing: O=S(=O)(C=1C=CC=C(C(N2CCC=3C=C(C(=CCe3C2)OC)OC)=O)C=1)N4CCCCC4
# [02:13:59] SMILES Parse Error: check for mistakes around position 37:
# [02:13:59] C(C(N2CCC=3C=C(C(=CCe3C2)OC)OC)=O)C=1)N4C
# [02:13:59] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:59] SMILES Parse Error: Failed parsing SMILES 'O=S(=O)(C=1C=CC=C(C(N2CCC=3C=C(C(=CCe3C2)OC)OC)=O)C=1)N4CCCCC4' for input: 'O=S(=O)(C=1C=CC=C(C(N2CCC=3C=C(C(=CCe3C2)OC)OC)=O)C=1)N4CCCCC4'
# [02:13:59] non-ring atom 11 marked aromatic
# [02:13:59] Explicit valence for atom # 11 C, 5, is greater than permitted
# [02:13:59] SMILES Parse Error: syntax error while parsing: CC=1C(C2=CC=CC=C2C(=1OC)=O)=O
# [02:13:59] SMILES Parse Error: check for mistakes around position 21:
# [02:13:59] CC=1C(C2=CC=CC=C2C(=1OC)=O)=O
# [02:13:59] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:59] SMILES Parse Error: Failed parsing SMILES 'CC=1C(C2=CC=CC=C2C(=1OC)=O)=O' for input: 'CC=1C(C2=CC=CC=C2C(=1OC)=O)=O'
# [02:13:59] SMILES Parse Error: syntax error while parsing: C1(C(Br)=C(NC(=O)N1OCCC)C)=e
# [02:13:59] SMILES Parse Error: check for mistakes around position 28:
# [02:13:59] )=C(NC(=O)N1OCCC)C)=e
# [02:13:59] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:59] SMILES Parse Error: Failed parsing SMILES 'C1(C(Br)=C(NC(=O)N1OCCC)C)=e' for input: 'C1(C(Br)=C(NC(=O)N1OCCC)C)=e'
# [02:13:59] SMILES Parse Error: syntax error while parsing: FC(F)(F)C(=)OCC
# [02:13:59] SMILES Parse Error: check for mistakes around position 12:
# [02:13:59] FC(F)(F)C(=)OCC
# [02:13:59] ~~~~~~~~~~~^
# [02:13:59] SMILES Parse Error: Failed parsing SMILES 'FC(F)(F)C(=)OCC' for input: 'FC(F)(F)C(=)OCC'
# [02:13:59] SMILES Parse Error: syntax error while parsing: ClC=1C(Cl)=CC(CSC2=NC=CC=NA)=CC=1
# [02:13:59] SMILES Parse Error: check for mistakes around position 27:
# [02:13:59] (Cl)=CC(CSC2=NC=CC=NA)=CC=1
# [02:13:59] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:59] SMILES Parse Error: Failed parsing SMILES 'ClC=1C(Cl)=CC(CSC2=NC=CC=NA)=CC=1' for input: 'ClC=1C(Cl)=CC(CSC2=NC=CC=NA)=CC=1'
# [02:13:59] SMILES Parse Error: syntax error while parsing: C=1C=CC2=C(C=1)C(=CC=C2)Cll
# [02:13:59] SMILES Parse Error: check for mistakes around position 27:
# [02:13:59] C2=C(C=1)C(=CC=C2)Cll
# [02:13:59] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:59] SMILES Parse Error: Failed parsing SMILES 'C=1C=CC2=C(C=1)C(=CC=C2)Cll' for input: 'C=1C=CC2=C(C=1)C(=CC=C2)Cll'
# [02:13:59] SMILES Parse Error: extra close parentheses while parsing: C(=O)(CNC(COC(C1=CC=CC=C1)=O)=O)C)O
# [02:13:59] SMILES Parse Error: check for mistakes around position 34:
# [02:13:59] (C1=CC=CC=C1)=O)=O)C)O
# [02:13:59] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:59] SMILES Parse Error: Failed parsing SMILES 'C(=O)(CNC(COC(C1=CC=CC=C1)=O)=O)C)O' for input: 'C(=O)(CNC(COC(C1=CC=CC=C1)=O)=O)C)O'
# [02:13:59] SMILES Parse Error: extra open parentheses while parsing: [N+]([O-])(=O)C1=CC=C(CCBrC=C1
# [02:13:59] SMILES Parse Error: check for mistakes around position 22:
# [02:13:59] N+]([O-])(=O)C1=CC=C(CCBrC=C1
# [02:13:59] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:59] SMILES Parse Error: Failed parsing SMILES '[N+]([O-])(=O)C1=CC=C(CCBrC=C1' for input: '[N+]([O-])(=O)C1=CC=C(CCBrC=C1'
# [02:13:59] SMILES Parse Error: syntax error while parsing: C(N)(O)C(C(C)=O)NC(=O)Ce
# [02:13:59] SMILES Parse Error: check for mistakes around position 24:
# [02:13:59] )(O)C(C(C)=O)NC(=O)Ce
# [02:13:59] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:59] SMILES Parse Error: Failed parsing SMILES 'C(N)(O)C(C(C)=O)NC(=O)Ce' for input: 'C(N)(O)C(C(C)=O)NC(=O)Ce'
# [02:13:59] SMILES Parse Error: syntax error while parsing: (C1=CC=CS1)#N
# [02:13:59] SMILES Parse Error: check for mistakes around position 1:
# [02:13:59] (C1=CC=CS1)#N
# [02:13:59] ^
# [02:13:59] SMILES Parse Error: Failed parsing SMILES '(C1=CC=CS1)#N' for input: '(C1=CC=CS1)#N'
# [02:13:59] SMILES Parse Error: syntax error while parsing: CC(C)N(C(C)=O)CC=CM
# [02:13:59] SMILES Parse Error: check for mistakes around position 19:
# [02:13:59] CC(C)N(C(C)=O)CC=CM
# [02:13:59] ~~~~~~~~~~~~~~~~~~^
# [02:13:59] SMILES Parse Error: Failed parsing SMILES 'CC(C)N(C(C)=O)CC=CM' for input: 'CC(C)N(C(C)=O)CC=CM'
# [02:13:59] Explicit valence for atom # 7 O, 5, is greater than permitted
# [02:13:59] non-ring atom 14 marked aromatic
# [02:13:59] Explicit valence for atom # 1 C, 7, is greater than permitted
# [02:13:59] SMILES Parse Error: extra open parentheses while parsing: CC(C)C=1N=C(C2=CC=C(C(CC(=O)O)C=C2F)SC=1
# [02:13:59] SMILES Parse Error: check for mistakes around position 12:
# [02:13:59] CC(C)C=1N=C(C2=CC=C(C(CC(=O)O)C=C2F)SC=1
# [02:13:59] ~~~~~~~~~~~^
# [02:13:59] SMILES Parse Error: Failed parsing SMILES 'CC(C)C=1N=C(C2=CC=C(C(CC(=O)O)C=C2F)SC=1' for input: 'CC(C)C=1N=C(C2=CC=C(C(CC(=O)O)C=C2F)SC=1'
# [02:13:59] SMILES Parse Error: extra close parentheses while parsing: O=S(=O)C1=CC=C(CCCO)C=C1)N
# [02:13:59] SMILES Parse Error: check for mistakes around position 25:
# [02:13:59] =O)C1=CC=C(CCCO)C=C1)N
# [02:13:59] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:59] SMILES Parse Error: Failed parsing SMILES 'O=S(=O)C1=CC=C(CCCO)C=C1)N' for input: 'O=S(=O)C1=CC=C(CCCO)C=C1)N'
# [02:13:59] SMILES Parse Error: extra close parentheses while parsing: C(C)OC(CC(C(=O)OCC)NC=O)CCCCSC=1C2=C(N=CN2)N=CN=1)=O
# [02:13:59] SMILES Parse Error: check for mistakes around position 50:
# [02:13:59] C=1C2=C(N=CN2)N=CN=1)=O
# [02:13:59] ~~~~~~~~~~~~~~~~~~~~^
# [02:13:59] SMILES Parse Error: Failed parsing SMILES 'C(C)OC(CC(C(=O)OCC)NC=O)CCCCSC=1C2=C(N=CN2)N=CN=1)=O' for input: 'C(C)OC(CC(C(=O)OCC)NC=O)CCCCSC=1C2=C(N=CN2)N=CN=1)=O'
# [02:13:59] SMILES Parse Error: syntax error while parsing: CC(C)C(NC(CN)=O)C(=O)NC(C(O)=O)CC1=CC=Ce=C1
# [02:13:59] SMILES Parse Error: check for mistakes around position 40:
# ...
# [02:14:00] SMILES Parse Error: check for mistakes around position 28:
# [02:14:00] 12CC(=O)C(C(=NOCC)CCE)C(O2)=O
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'C1CCCCC12CC(=O)C(C(=NOCC)CCE)C(O2)=O' for input: 'C1CCCCC12CC(=O)C(C(=NOCC)CCE)C(O2)=O'
# [02:14:00] SMILES Parse Error: syntax error while parsing: O=S(=O)(C1=CC=CC2=C1N=Ca=C2)C3=CC=CC=C3
# [02:14:00] SMILES Parse Error: check for mistakes around position 24:
# [02:14:00] (=O)(C1=CC=CC2=C1N=Ca=C2)C3=CC=CC=C3
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'O=S(=O)(C1=CC=CC2=C1N=Ca=C2)C3=CC=CC=C3' for input: 'O=S(=O)(C1=CC=CC2=C1N=Ca=C2)C3=CC=CC=C3'
# [02:14:00] SMILES Parse Error: extra close parentheses while parsing: C(C)(=NOC(=O)N(C)SN(ClCCC)=O)C)SC
# [02:14:00] SMILES Parse Error: check for mistakes around position 31:
# [02:14:00] =O)N(C)SN(ClCCC)=O)C)SC
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'C(C)(=NOC(=O)N(C)SN(ClCCC)=O)C)SC' for input: 'C(C)(=NOC(=O)N(C)SN(ClCCC)=O)C)SC'
# [02:14:00] Can't kekulize mol.  Unkekulized atoms: 8
# [02:14:00] SMILES Parse Error: syntax error while parsing: C(CC(CCCCC)C(O)=O)Ce
# [02:14:00] SMILES Parse Error: check for mistakes around position 20:
# [02:14:00] C(CC(CCCCC)C(O)=O)Ce
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'C(CC(CCCCC)C(O)=O)Ce' for input: 'C(CC(CCCCC)C(O)=O)Ce'
# [02:14:00] SMILES Parse Error: unclosed ring for input: 'OC1=C2C(=COC(=O)N)C3(N(C2=C(O)C(=C1N=C4SC=CN4)C)CC5CN5)OC'
# [02:14:00] SMILES Parse Error: extra open parentheses while parsing: CN(C)C1=CC(=CC=C1)COC(N(CC)=O
# [02:14:00] SMILES Parse Error: check for mistakes around position 22:
# [02:14:00] N(C)C1=CC(=CC=C1)COC(N(CC)=O
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'CN(C)C1=CC(=CC=C1)COC(N(CC)=O' for input: 'CN(C)C1=CC(=CC=C1)COC(N(CC)=O'
# [02:14:00] SMILES Parse Error: unclosed ring for input: 'C(CCCCCC)C(=O)OC(C=CC=CC=C1)C(NC2C3N(C(C(O)=O)=C(CS3)C)C2=O)=O'
# [02:14:00] SMILES Parse Error: syntax error while parsing: C(OC)ONC=NC=1C=C(OCC#C)C(=C(Cl)C=1)OCC#CD
# [02:14:00] SMILES Parse Error: check for mistakes around position 41:
# [02:14:00] #C)C(=C(Cl)C=1)OCC#CD
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'C(OC)ONC=NC=1C=C(OCC#C)C(=C(Cl)C=1)OCC#CD' for input: 'C(OC)ONC=NC=1C=C(OCC#C)C(=C(Cl)C=1)OCC#CD'
# [02:14:00] Explicit valence for atom # 7 C, 5, is greater than permitted
# [02:14:00] SMILES Parse Error: extra close parentheses while parsing: CCN(CC)C(=O)COC=O)C=1C=CC=CC=1
# [02:14:00] SMILES Parse Error: check for mistakes around position 18:
# [02:14:00] CCN(CC)C(=O)COC=O)C=1C=CC=CC=1
# [02:14:00] ~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'CCN(CC)C(=O)COC=O)C=1C=CC=CC=1' for input: 'CCN(CC)C(=O)COC=O)C=1C=CC=CC=1'
# [02:14:00] SMILES Parse Error: syntax error while parsing: C(CCC)(C(N)=O)N1N=gC=2C1=CC=CC=2
# [02:14:00] SMILES Parse Error: check for mistakes around position 19:
# [02:14:00] C(CCC)(C(N)=O)N1N=gC=2C1=CC=CC=2
# [02:14:00] ~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'C(CCC)(C(N)=O)N1N=gC=2C1=CC=CC=2' for input: 'C(CCC)(C(N)=O)N1N=gC=2C1=CC=CC=2'
# [02:14:00] SMILES Parse Error: extra open parentheses while parsing: C(CCCOCl
# [02:14:00] SMILES Parse Error: check for mistakes around position 2:
# [02:14:00] C(CCCOCl
# [02:14:00] ~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'C(CCCOCl' for input: 'C(CCCOCl'
# [02:14:00] SMILES Parse Error: syntax error while parsing: N#CC(CN1N=CN=C1)(C2=CC=CG=C2)CCC3=CC=C(C=C3)Cl
# [02:14:00] SMILES Parse Error: check for mistakes around position 25:
# [02:14:00] (CN1N=CN=C1)(C2=CC=CG=C2)CCC3=CC=C(C=C3)C
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'N#CC(CN1N=CN=C1)(C2=CC=CG=C2)CCC3=CC=C(C=C3)Cl' for input: 'N#CC(CN1N=CN=C1)(C2=CC=CG=C2)CCC3=CC=C(C=C3)Cl'
# [02:14:00] SMILES Parse Error: syntax error while parsing: ONC(C)=a
# [02:14:00] SMILES Parse Error: check for mistakes around position 8:
# [02:14:00] ONC(C)=a
# [02:14:00] ~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'ONC(C)=a' for input: 'ONC(C)=a'
# [02:14:00] Explicit valence for atom # 11 C, 5, is greater than permitted
# [02:14:00] SMILES Parse Error: syntax error while parsing: OCCCCCN1N=NC2=CC=CC=C12T
# [02:14:00] SMILES Parse Error: check for mistakes around position 24:
# [02:14:00] CCCN1N=NC2=CC=CC=C12T
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'OCCCCCN1N=NC2=CC=CC=C12T' for input: 'OCCCCCN1N=NC2=CC=CC=C12T'
# [02:14:00] Explicit valence for atom # 6 C, 5, is greater than permitted
# [02:14:00] SMILES Parse Error: syntax error while parsing: C1=CC=C2C(C(CC(=O)C2=C1)=NCCO)=OZ
# [02:14:00] SMILES Parse Error: check for mistakes around position 33:
# [02:14:00] CC(=O)C2=C1)=NCCO)=OZ
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'C1=CC=C2C(C(CC(=O)C2=C1)=NCCO)=OZ' for input: 'C1=CC=C2C(C(CC(=O)C2=C1)=NCCO)=OZ'
# [02:14:00] SMILES Parse Error: syntax error while parsing: C=1(C=CC(OCC(O)=O)=CC=1)OCr
# [02:14:00] SMILES Parse Error: check for mistakes around position 27:
# [02:14:00] CC(OCC(O)=O)=CC=1)OCr
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'C=1(C=CC(OCC(O)=O)=CC=1)OCr' for input: 'C=1(C=CC(OCC(O)=O)=CC=1)OCr'
# [02:14:00] Explicit valence for atom # 16 O, 5, is greater than permitted
# [02:14:00] SMILES Parse Error: syntax error while parsing: OC(O)C(CC(C)C)NC(C(Na(C(N)CC(C)C)=O)C(C)=O)=O
# [02:14:00] SMILES Parse Error: check for mistakes around position 21:
# [02:14:00] OC(O)C(CC(C)C)NC(C(Na(C(N)CC(C)C)=O)C(C)=
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'OC(O)C(CC(C)C)NC(C(Na(C(N)CC(C)C)=O)C(C)=O)=O' for input: 'OC(O)C(CC(C)C)NC(C(Na(C(N)CC(C)C)=O)C(C)=O)=O'
# [02:14:00] SMILES Parse Error: syntax error while parsing: C1=CC(NC(N1C2CC(N=[N+]=[N-])C(CO)O2)=O)=Na
# [02:14:00] SMILES Parse Error: check for mistakes around position 42:
# [02:14:00] ]=[N-])C(CO)O2)=O)=Na
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'C1=CC(NC(N1C2CC(N=[N+]=[N-])C(CO)O2)=O)=Na' for input: 'C1=CC(NC(N1C2CC(N=[N+]=[N-])C(CO)O2)=O)=Na'
# [02:14:00] non-ring atom 13 marked aromatic
# [02:14:00] SMILES Parse Error: syntax error while parsing: CC(C)CC(N)C(=O)NC(C(NC(C(C)C)C(TC(C(O)=O)CC=1C=CC=CC=1)=O)=O)CC(C)C
# [02:14:00] SMILES Parse Error: check for mistakes around position 32:
# [02:14:00] (=O)NC(C(NC(C(C)C)C(TC(C(O)=O)CC=1C=CC=CC
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'CC(C)CC(N)C(=O)NC(C(NC(C(C)C)C(TC(C(O)=O)CC=1C=CC=CC=1)=O)=O)CC(C)C' for input: 'CC(C)CC(N)C(=O)NC(C(NC(C(C)C)C(TC(C(O)=O)CC=1C=CC=CC=1)=O)=O)CC(C)C'
# [02:14:00] Explicit valence for atom # 18 C, 5, is greater than permitted
# [02:14:00] SMILES Parse Error: syntax error while parsing: [N+]([O-])(=O)C1=CC=C(C=CC(O)=O)C=C1r
# [02:14:00] SMILES Parse Error: check for mistakes around position 37:
# [02:14:00] =CC=C(C=CC(O)=O)C=C1r
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES '[N+]([O-])(=O)C1=CC=C(C=CC(O)=O)C=C1r' for input: '[N+]([O-])(=O)C1=CC=C(C=CC(O)=O)C=C1r'
# [02:14:00] SMILES Parse Error: syntax error while parsing: CC(C)(C)C(=O)NC1=CC=C(Cl)C(Cl)=C1M
# [02:14:00] SMILES Parse Error: check for mistakes around position 34:
# [02:14:00] NC1=CC=C(Cl)C(Cl)=C1M
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'CC(C)(C)C(=O)NC1=CC=C(Cl)C(Cl)=C1M' for input: 'CC(C)(C)C(=O)NC1=CC=C(Cl)C(Cl)=C1M'
# [02:14:00] SMILES Parse Error: syntax error while parsing: C(CN(C1=NC=2C(=CC=CC=2)O1)N)C#Nl
# [02:14:00] SMILES Parse Error: check for mistakes around position 32:
# [02:14:00] 2C(=CC=CC=2)O1)N)C#Nl
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'C(CN(C1=NC=2C(=CC=CC=2)O1)N)C#Nl' for input: 'C(CN(C1=NC=2C(=CC=CC=2)O1)N)C#Nl'
# [02:14:00] SMILES Parse Error: syntax error while parsing: C(C(=O)N(C)C(CC=1C=CC=CC=1)C(N)=O)(CC2=CC=CC=C2)NC(=O)C(CC=3C=CC=CC=3)NC(C)=Og
# [02:14:00] SMILES Parse Error: check for mistakes around position 78:
# [02:14:00] C=3C=CC=CC=3)NC(C)=Og
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'C(C(=O)N(C)C(CC=1C=CC=CC=1)C(N)=O)(CC2=CC=CC=C2)NC(=O)C(CC=3C=CC=CC=3)NC(C)=Og' for input: 'C(C(=O)N(C)C(CC=1C=CC=CC=1)C(N)=O)(CC2=CC=CC=C2)NC(=O)C(CC=3C=CC=CC=3)NC(C)=Og'
# [02:14:00] SMILES Parse Error: syntax error while parsing: CN(C)CCOC(=O)C=1C=CC=CC=1E
# [02:14:00] SMILES Parse Error: check for mistakes around position 26:
# [02:14:00] CCOC(=O)C=1C=CC=CC=1E
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'CN(C)CCOC(=O)C=1C=CC=CC=1E' for input: 'CN(C)CCOC(=O)C=1C=CC=CC=1E'
# [02:14:00] SMILES Parse Error: extra close parentheses while parsing: CC(C)N(CC)C)C(=O)N(C)SN(C)C(ON=C(C)SC)=O
# [02:14:00] SMILES Parse Error: check for mistakes around position 12:
# [02:14:00] CC(C)N(CC)C)C(=O)N(C)SN(C)C(ON=C(C)SC)=O
# [02:14:00] ~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'CC(C)N(CC)C)C(=O)N(C)SN(C)C(ON=C(C)SC)=O' for input: 'CC(C)N(CC)C)C(=O)N(C)SN(C)C(ON=C(C)SC)=O'
# [02:14:00] non-ring atom 9 marked aromatic
# [02:14:00] SMILES Parse Error: syntax error while parsing: C1=CC(CC2=C(C)CC3C(C(CC4eC3CCC4(OC(C)=O)C(=O)C)C)O)(F)C12C)=O
# [02:14:00] SMILES Parse Error: check for mistakes around position 25:
# [02:14:00] C(CC2=C(C)CC3C(C(CC4eC3CCC4(OC(C)=O)C(=O)
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'C1=CC(CC2=C(C)CC3C(C(CC4eC3CCC4(OC(C)=O)C(=O)C)C)O)(F)C12C)=O' for input: 'C1=CC(CC2=C(C)CC3C(C(CC4eC3CCC4(OC(C)=O)C(=O)C)C)O)(F)C12C)=O'
# [02:14:00] SMILES Parse Error: syntax error while parsing: O=C(C=1C=CC(=CC=1)OC(C=2C=C(C=C(OC)C=2)OC)=O)lC
# [02:14:00] SMILES Parse Error: check for mistakes around position 46:
# [02:14:00] =C(C=C(OC)C=2)OC)=O)lC
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'O=C(C=1C=CC(=CC=1)OC(C=2C=C(C=C(OC)C=2)OC)=O)lC' for input: 'O=C(C=1C=CC(=CC=1)OC(C=2C=C(C=C(OC)C=2)OC)=O)lC'
# [02:14:00] Explicit valence for atom # 10 C, 5, is greater than permitted
# [02:14:00] non-ring atom 13 marked aromatic
# [02:14:00] SMILES Parse Error: syntax error while parsing: CN(C)C1=CC(=CC(N(C)C)=C1OC)CC2=CNe(=N)NC2=N
# [02:14:00] SMILES Parse Error: check for mistakes around position 34:
# [02:14:00] C(N(C)C)=C1OC)CC2=CNe(=N)NC2=N
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'CN(C)C1=CC(=CC(N(C)C)=C1OC)CC2=CNe(=N)NC2=N' for input: 'CN(C)C1=CC(=CC(N(C)C)=C1OC)CC2=CNe(=N)NC2=N'
# [02:14:00] SMILES Parse Error: syntax error while parsing: O(CC)C1=CC=CC=C1OCCM
# [02:14:00] SMILES Parse Error: check for mistakes around position 20:
# [02:14:00] O(CC)C1=CC=CC=C1OCCM
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'O(CC)C1=CC=CC=C1OCCM' for input: 'O(CC)C1=CC=CC=C1OCCM'
# [02:14:00] SMILES Parse Error: syntax error while parsing: CC()CC(C(NC(CC=1C=CC(O)=CC=1)C(=O)O)=O)N
# [02:14:00] SMILES Parse Error: check for mistakes around position 4:
# [02:14:00] CC()CC(C(NC(CC=1C=CC(O)=CC=1)C(=O)O)=O)N
# [02:14:00] ~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'CC()CC(C(NC(CC=1C=CC(O)=CC=1)C(=O)O)=O)N' for input: 'CC()CC(C(NC(CC=1C=CC(O)=CC=1)C(=O)O)=O)N'
# [02:14:00] SMILES Parse Error: syntax error while parsing: OCC1C(C(C(O1)N2C=C(C)C(=N)NC2=O)O)Og
# [02:14:00] SMILES Parse Error: check for mistakes around position 36:
# [02:14:00] C=C(C)C(=N)NC2=O)O)Og
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'OCC1C(C(C(O1)N2C=C(C)C(=N)NC2=O)O)Og' for input: 'OCC1C(C(C(O1)N2C=C(C)C(=N)NC2=O)O)Og'
# [02:14:00] Explicit valence for atom # 13 Cl, 4, is greater than permitted
# [02:14:00] SMILES Parse Error: extra open parentheses while parsing: O(C(NC=1C=CC(=CC=1)CC)=OC
# [02:14:00] SMILES Parse Error: check for mistakes around position 2:
# [02:14:00] O(C(NC=1C=CC(=CC=1)CC)=OC
# [02:14:00] ~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'O(C(NC=1C=CC(=CC=1)CC)=OC' for input: 'O(C(NC=1C=CC(=CC=1)CC)=OC'
# [02:14:00] SMILES Parse Error: extra close parentheses while parsing: C1CCCCN1CCOC=O)NC=2C(=CC=CC=2)OCCCCC
# [02:14:00] SMILES Parse Error: check for mistakes around position 15:
# [02:14:00] C1CCCCN1CCOC=O)NC=2C(=CC=CC=2)OCCCCC
# [02:14:00] ~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'C1CCCCN1CCOC=O)NC=2C(=CC=CC=2)OCCCCC' for input: 'C1CCCCN1CCOC=O)NC=2C(=CC=CC=2)OCCCCC'
# [02:14:00] SMILES Parse Error: extra close parentheses while parsing: N1C=2C(=CC=CC=2CC=N1)=N)C
# [02:14:00] SMILES Parse Error: check for mistakes around position 24:
# [02:14:00] =2C(=CC=CC=2CC=N1)=N)C
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'N1C=2C(=CC=CC=2CC=N1)=N)C' for input: 'N1C=2C(=CC=CC=2CC=N1)=N)C'
# [02:14:00] SMILES Parse Error: syntax error while parsing: C1CCCCmN2N=C3C=CC(NC(=O)C)=CC3=N2
# [02:14:00] SMILES Parse Error: check for mistakes around position 7:
# [02:14:00] C1CCCCmN2N=C3C=CC(NC(=O)C)=CC3=N2
# [02:14:00] ~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'C1CCCCmN2N=C3C=CC(NC(=O)C)=CC3=N2' for input: 'C1CCCCmN2N=C3C=CC(NC(=O)C)=CC3=N2'
# [02:14:00] Explicit valence for atom # 12 C, 7, is greater than permitted
# [02:14:00] SMILES Parse Error: syntax error while parsing: CC()CCCOC=1C(=CC(CC(O)=O)=CC=1)OC
# [02:14:00] SMILES Parse Error: check for mistakes around position 4:
# [02:14:00] CC()CCCOC=1C(=CC(CC(O)=O)=CC=1)OC
# [02:14:00] ~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'CC()CCCOC=1C(=CC(CC(O)=O)=CC=1)OC' for input: 'CC()CCCOC=1C(=CC(CC(O)=O)=CC=1)OC'
# [02:14:00] Explicit valence for atom # 1 C, 5, is greater than permitted
# [02:14:00] SMILES Parse Error: syntax error while parsing: C=1(C(Cl)=C(Cl)C=C(C=1)OC)l
# [02:14:00] SMILES Parse Error: check for mistakes around position 27:
# [02:14:00] Cl)=C(Cl)C=C(C=1)OC)l
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'C=1(C(Cl)=C(Cl)C=C(C=1)OC)l' for input: 'C=1(C(Cl)=C(Cl)C=C(C=1)OC)l'
# [02:14:00] SMILES Parse Error: syntax error while parsing: CC=1N2C(=NC(=C(CC)C2=O)C)C=CC=1t
# [02:14:00] SMILES Parse Error: check for mistakes around position 32:
# [02:14:00] (=C(CC)C2=O)C)C=CC=1t
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'CC=1N2C(=NC(=C(CC)C2=O)C)C=CC=1t' for input: 'CC=1N2C(=NC(=C(CC)C2=O)C)C=CC=1t'
# [02:14:00] Explicit valence for atom # 4 C, 7, is greater than permitted
# [02:14:00] Can't kekulize mol.  Unkekulized atoms: 12
# [02:14:00] SMILES Parse Error: syntax error while parsing: CC1(C)CC2=NC3=NC=NN3C(C=4C(=CC=C(Br)C=)OCC)C2C(=O)C1
# [02:14:00] SMILES Parse Error: check for mistakes around position 39:
# [02:14:00] N3C(C=4C(=CC=C(Br)C=)OCC)C2C(=O)C1
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'CC1(C)CC2=NC3=NC=NN3C(C=4C(=CC=C(Br)C=)OCC)C2C(=O)C1' for input: 'CC1(C)CC2=NC3=NC=NN3C(C=4C(=CC=C(Br)C=)OCC)C2C(=O)C1'
# [02:14:00] non-ring atom 22 marked aromatic
# [02:14:00] non-ring atom 0 marked aromatic
# [02:14:00] SMILES Parse Error: syntax error while parsing: CC(C)OC1=CC(=CC=C1)NC(C2=CCDCC=C2C)=O
# [02:14:00] SMILES Parse Error: check for mistakes around position 28:
# [02:14:00] 1=CC(=CC=C1)NC(C2=CCDCC=C2C)=O
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'CC(C)OC1=CC(=CC=C1)NC(C2=CCDCC=C2C)=O' for input: 'CC(C)OC1=CC(=CC=C1)NC(C2=CCDCC=C2C)=O'
# [02:14:00] SMILES Parse Error: syntax error while parsing: C(C=1C(NC(=O)C)=CC=C(Br)C=1)CZ
# [02:14:00] SMILES Parse Error: check for mistakes around position 30:
# [02:14:00] (=O)C)=CC=C(Br)C=1)CZ
# [02:14:00] ~~~~~~~~~~~~~~~~~~~~^
# [02:14:00] SMILES Parse Error: Failed parsing SMILES 'C(C=1C(NC(=O)C)=CC=C(Br)C=1)CZ' for input: 'C(C=1C(NC(=O)C)=CC=C(Br)C=1)CZ'
# Number of invalid SMILES removed: 430
# Number of duplicate SMILES removed: 963

# %% [markdown]
# ## Вычисление молекулярных дескрипторов
# В данном блоке подгружаем необходимые дескрипторы

# %%
def add_top_descriptors(df, selected_descriptors):
    rdkit_funcs = {
        'FpDensityMorgan1': Descriptors.FpDensityMorgan1,
        'FpDensityMorgan2': Descriptors.FpDensityMorgan2,
        'HeavyAtomMolWt': Descriptors.HeavyAtomMolWt,
        'MolWt': Descriptors.MolWt,
        'NumHDonors': Descriptors.NumHDonors,
        'NumHAcceptors': Descriptors.NumHAcceptors,
        'fr_COO': Chem.Fragments.fr_COO,
        'fr_Al_COO': Chem.Fragments.fr_Al_COO,
        'fr_Ar_N': Chem.Fragments.fr_Ar_N,
        'fr_Al_OH': Chem.Fragments.fr_Al_OH,
        'fr_Ar_NH': Chem.Fragments.fr_Ar_NH,
        'fr_quatN': Chem.Fragments.fr_quatN,
        'BertzCT': Chem.GraphDescriptors.BertzCT,
    }

    rdmol_funcs = {
        'NumRings': rdMolDescriptors.CalcNumRings,
        'NumAromaticRings': rdMolDescriptors.CalcNumAromaticRings,
        'NumAromaticCarbocycles': rdMolDescriptors.CalcNumAromaticCarbocycles,
        'NumHeteroatoms': rdMolDescriptors.CalcNumHeteroatoms,
        'TPSA': rdMolDescriptors.CalcTPSA,
        'LabuteASA': rdMolDescriptors.CalcLabuteASA,
        'CalcKappa3': rdMolDescriptors.CalcKappa3,
    }

    mordred_dict = {
        'SLogP': descriptors.SLogP,
        'PEOE_VSA6': descriptors.MoeType.PEOE_VSA(6),
        'PEOE_VSA1': descriptors.MoeType.PEOE_VSA(1),
        'C2SP2': descriptors.CarbonTypes.CarbonTypes(2, 2),
        'ZMIC1': descriptors.InformationContent.ZModifiedIC(1),
        'ZMIC2': descriptors.InformationContent.ZModifiedIC(2),
        'NaasC': descriptors.EState.AtomTypeEState ('count', 'aasC'),
        'NsNh2': descriptors.EState.AtomTypeEState ('count', 'sNH2'),
        'NsOH': descriptors.EState.AtomTypeEState ('count', 'sOH'),
        'NdO': descriptors.EState.AtomTypeEState ('count', 'dO'),
        'nX': descriptors.AtomCount.AtomCount('X'),
        'nN': descriptors.AtomCount.AtomCount('N'),
        'VSA_EState6': descriptors.MoeType.VSA_EState(6),
        'SMR_VSA7': descriptors.MoeType.SMR_VSA(7),
        'AATS1p': descriptors.Autocorrelation.AATS(1, 'p'),
        'AATS1v': descriptors.Autocorrelation.AATS(1, 'v'),
        'AATS1i': descriptors.Autocorrelation.AATS(1, 'i'),
        'AATS2p': descriptors.Autocorrelation.AATS(2, 'p'),
        'AATS2v': descriptors.Autocorrelation.AATS(2, 'v'),
        'AATS1se': descriptors.Autocorrelation.AATS(1, 'se'),
        'AATS0se': descriptors.Autocorrelation.AATS(0, 'se'),
        'AATS4s': descriptors.Autocorrelation.AATS(4, 's'),
        'MATS1Z': descriptors.Autocorrelation.MATS(1, 'Z'),
        'MATS2d': descriptors.Autocorrelation.MATS(2, 'd'),
        'MATS1m': descriptors.Autocorrelation.MATS(1, 'm'),
        'MATS1pe': descriptors.Autocorrelation.MATS(1, 'pe'),
        'MATS1se': descriptors.Autocorrelation.MATS(1, 'se'),
        'SlogP_VSA7': descriptors.MoeType.SlogP_VSA(7),
        'SlogP_VSA8': descriptors.MoeType.SlogP_VSA(8),
        'nAcid': descriptors.AcidBase.AcidicGroupCount(),
        'nBase': descriptors.AcidBase.BasicGroupCount(),
        'FilterItLogS': descriptors.LogS.LogS(),
        'nBondsM': descriptors.BondCount.BondCount('multiple', False),
        'MIC0': descriptors.InformationContent.ModifiedIC(0),
        'EState_VSA5': descriptors.MoeType.EState_VSA(5),
        'IC5': descriptors.InformationContent.InformationContent(5),
        'IC0': descriptors.InformationContent.InformationContent(0)
    }

    rdkit_selected = {k: f for k, f in rdkit_funcs.items() if k in selected_descriptors}
    rdmol_selected = {k: f for k, f in rdmol_funcs.items() if k in selected_descriptors}
    mordred_selected = {k: f for k, f in mordred_dict.items() if k in selected_descriptors}

    # Подготовка Mordred-калькулятора
    mordred_calc = Calculator(list(mordred_selected.values()), ignore_3D=True) if mordred_selected else None

    def compute_all(smiles):
        mol = Chem.MolFromSmiles(smiles)
        if mol is None:
            return {name: np.nan for name in selected_descriptors}

        result = {}

        for name, func in rdkit_selected.items():
            result[name] = func(mol)

        for name, func in rdmol_selected.items():
            result[name] = func(mol)

        if mordred_calc:
            mordred_vals = mordred_calc(mol)
            for i, name in enumerate(mordred_selected.keys()):
                result[name] = mordred_vals[i]

        return result

    descriptors_df = df['SMILES'].apply(compute_all).apply(pd.Series)
    df_final = pd.concat([df, descriptors_df], axis=1)

    return df_final

def clean_data(df):
   df = df.replace([np.inf, -np.inf], np.nan).dropna(axis=1)
   df_clear = df.rename(str, axis="columns") 
   return df_clear

# %%
df = add_top_descriptors(df, DESCRIPTORS)
df = clean_data(df)

# %% [markdown]
# Так как заранее подготовленных валидационных данных у нас нет, создаём набор из тренировочных данных. Так как таргетная переменная - непрерывные значения, то используем псевдо-стратификацию данных, чтобы не было дисбаланса. Дробим данные на 20 групп (квантилей) и проводим разделение на train и valid, используя train_test_split.

# %%
# Создаём квазикатегориальную переменную для стратификации
df['stratify_bins'] = pd.qcut(df['LogP'], q=20)  # q=кол-во квантилей (групп)

train_df, val_df = train_test_split(
    df, test_size=0.2, random_state=666, stratify=df['stratify_bins']
)

train_df = train_df.drop(columns='stratify_bins')
val_df = val_df.drop(columns='stratify_bins')

# %% [markdown]
# Создаём объекты MoleculeDatapoint. Chemprop требует данные в формате MoleculeDatapoint для обработки молекулярных графов.

# %%
def create_molecule_datapoints(df, smiles_column, target_columns=None, descriptor_columns=None):
    if target_columns is not None:
        ys = df[target_columns].to_numpy()

    all_data = []
    for i, (_, row) in enumerate(df.iterrows()):
        if descriptor_columns is not None and descriptor_columns != []:
            descriptors = np.array(row[descriptor_columns], dtype=float).tolist()

            if target_columns is not None:
                datapoint = MoleculeDatapoint.from_smi(row[smiles_column], ys[i], x_d=np.array(descriptors))
            else:
                datapoint = MoleculeDatapoint.from_smi(row[smiles_column], x_d=np.array(descriptors))
        else:
            if target_columns is not None:
                datapoint = MoleculeDatapoint.from_smi(row[smiles_column], ys[i])
            else:
                datapoint = MoleculeDatapoint.from_smi(row[smiles_column])
        all_data.append(datapoint)

    return all_data

# %% [markdown]
# ## Optuna
# Функция оптимизирует гиперпараметры и дескрипторы, используя Optuna с TPE и MedianPruner.
# Гиперпараметры:
# agg_type: Тип агрегации (mean, sum, norm, attentive).
# bias: Использование смещения в слоях (True/False).
# d_h: Размер скрытых слоёв в MPNN (300–2000).
# hidden_dim: Размер скрытых слоёв в FFN (1000–4000).
# depth: Глубина MPNN (2–8).
# ffn_num_layers: Количество слоёв FFN (2–10).
# batch_norm: Использование нормализации пакета (True/False).
# selected_descriptors: Бинарный выбор дескрипторов.
#
# TPE с multivariate=True: Учитывает корреляции между параметрами, улучшая эффективность поиска.
# MedianPruner: Останавливает неперспективные испытания.
# EarlyStopping: Предотвращает переобучение, останавливая обучение, если validation loss не улучшается 7 эпох.

# %%
def optimize_chemprop_model(train_df, val_df, descriptor_cols, target_col='LogP', n_trials=100, seed=666):
    """
    Оптимизирует гиперпараметры модели Chemprop и выбор дескрипторов с помощью Optuna.

    Параметры:
    - train_df: pandas DataFrame с тренировочными данными (SMILES, target_col, descriptor_cols)
    - val_df: pandas DataFrame с валидационными данными (SMILES, target_col, descriptor_cols)
    - descriptor_cols: список дескрипторов для выбора
    - target_col: имя целевой колонки
    - n_trials: количество испытаний Optuna
    - seed: начальное число для воспроизводимости

    Возвращает:
    - best_params: словарь с лучшими гиперпараметрами и выбранными дескрипторами
    - best_value: лучшая метрика (RMSE на валидационной выборке)
    """

    def objective(trial):
        # Установка seed для воспроизводимости
        random.seed(seed)
        np.random.seed(seed)
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        pl.seed_everything(seed)

        # Подбор гиперпараметров
        agg_type = trial.suggest_categorical('agg_type', ['mean', 'sum', 'norm', 'attentive'])
        bias = trial.suggest_categorical('bias', [True, False])
        d_h = trial.suggest_categorical('d_h', [300, 400, 500, 600, 700, 800, 900, 1000, 1250, 1500, 1750, 2000])
        hidden_dim = trial.suggest_categorical('hidden_dim', [1000, 1250, 1500, 1600, 1700, 1800, 1900, 2000, 2250, 2500, 2750, 3000, 3250, 3500, 3750, 4000])
        depth = trial.suggest_int('depth', 2, 8)
        ffn_num_layers = trial.suggest_int('ffn_num_layers', 2, 10)
        batch_norm = trial.suggest_categorical('batch_norm', [True, False])

        # Подбор дескрипторов
        selected_descriptors = [desc for desc in descriptor_cols if trial.suggest_int(f'{desc}', 0, 1)]

        # Нормализация целевой переменной
        logp_scaler = StandardScaler()
        logp_scaler.fit(train_df[[target_col]])

        # Нормализация дескрипторов, если они выбраны
        if selected_descriptors:
            desc_scaler = StandardScaler()
            desc_scaler.fit(train_df[selected_descriptors])
            X_d_transform = ScaleTransform.from_standard_scaler(desc_scaler)
        else:
            desc_scaler = None
            X_d_transform = None

        # Создание датасетов
        train_datapoints = create_molecule_datapoints(train_df, 'SMILES', ['LogP'], selected_descriptors)
        val_datapoints = create_molecule_datapoints(val_df, 'SMILES', ['LogP'], selected_descriptors)

        featurizer = SimpleMoleculeMolGraphFeaturizer()

        train_dataset = MoleculeDataset(train_datapoints, featurizer)
        target_scaler = train_dataset.normalize_targets(logp_scaler)
        descriptors_scaler = train_dataset.normalize_inputs("X_d", desc_scaler)

        val_dataset = MoleculeDataset(val_datapoints, featurizer)
        val_dataset.normalize_targets(target_scaler)
        val_dataset.normalize_inputs("X_d", descriptors_scaler)
        
        num_workers = 10 if torch.cuda.is_available() else 0
        train_loader = build_dataloader(train_dataset, num_workers=num_workers)
        val_loader = build_dataloader(val_dataset, num_workers=num_workers, shuffle=False)

        # Настройка модели
        mp = BondMessagePassing(d_h=d_h, depth=depth, bias=bias)

        if agg_type == 'attentive':
            agg = AttentiveAggregation(output_size=d_h)
        else:
            agg_map = {
                'mean': MeanAggregation,
                'sum': SumAggregation,
                'norm': NormAggregation
            }
            agg = agg_map[agg_type]()

        input_dim = mp.output_dim + len(selected_descriptors) if selected_descriptors else mp.output_dim

        ffn = RegressionFFN(
            input_dim=input_dim,
            hidden_dim=hidden_dim,
            n_layers=ffn_num_layers,
            criterion=RMSE(),
            output_transform=UnscaleTransform.from_standard_scaler(target_scaler)
        )

        mpnn = MPNN(mp, agg, ffn, batch_norm, [RMSE()], X_d_transform=X_d_transform)
        
        # Настройка тренера
        early_stop_callback = EarlyStopping(monitor='val_loss', patience=7, mode='min')
        
        # Класс-обёртка, без неё может подтекать
        class OptunaPruning(PyTorchLightningPruningCallback, pl.Callback):
            def __init__(self, *args, **kwargs):
                super().__init__(*args, **kwargs)
        
        pruner = OptunaPruning(trial, monitor='val_loss')
        trainer = pl.Trainer(
            max_epochs=40,
            accelerator='auto',
            devices=1,
            enable_progress_bar=False,
            enable_checkpointing=False,
            callbacks=[early_stop_callback, pruner],
            logger=False,
            deterministic=True
        )

        # Обучение
        trainer.fit(mpnn, train_loader, val_loader)

        # Получение метрики
        val_rmse = trainer.callback_metrics['val_loss'].item()
        print(f'Validation RMSE: {val_rmse}')
        return val_rmse

    # Создание и запуск оптимизации
    study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=seed, multivariate=True, group=True), pruner=MedianPruner(n_startup_trials=10, n_warmup_steps=5, interval_steps=1))
    study.optimize(objective, n_trials=n_trials)

    # Получение лучших параметров
    best_trial = study.best_trial
    best_params = best_trial.params
    selected_descriptors = [desc for desc in descriptor_cols if best_params.get(f'{desc}', 0) == 1]
    best_params['selected_descriptors'] = selected_descriptors
    best_params['agg_type'] = best_trial.params['agg_type']
    best_params['bias'] = best_trial.params['bias']
    best_params['batch_norm'] = best_trial.params['batch_norm']
    best_params['hidden_dim'] = best_trial.params['hidden_dim']
    best_params['depth'] = best_trial.params['depth']
    best_params['ffn_num_layers'] = best_trial.params['ffn_num_layers']
    best_params['d_h'] = best_trial.params['d_h']

    return best_params, best_trial.value

# %%
best_params, best_value = optimize_chemprop_model(train_df, val_df, DESCRIPTORS, target_col='LogP', n_trials=1000, seed=666)
print(f"Лучшая RMSE: {best_value}")
print(f"Лучшие параметры: {best_params}")

# %% [markdown]
# ## Сохранение результатов
# Выводит словарик лучших параметров, который можно скопировать и перенести в model_train_and_inference.ipynb. На всякий случай сохраняет .txt файл с результатами в ./data

# %%
timestamp = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
filename = f'./data/optuna_optimization_log_{timestamp}.txt'

with open(filename, 'w') as f:
    f.write(f'Best RMSE: {best_value:.4f}\n')
    f.write("best_params = {\n")
    for key, value in best_params.items():
        f.write(f"    {repr(key)}: {repr(value)},\n")
    f.write("}\n")
